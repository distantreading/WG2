# %% [markdown]
# *Distant reading NER Training School*
#
# *24.3.2021.*
# ## NER Processing using NLP tools (spaCy)
#
# ### Benedikt Perak
# Cultural Complexity Lab - University of Rijeka
#
# bperak@uniri.hr

# %% [markdown]
# *Before we begin*
#
# If you want to edit the Jupyter Notebook in your Google Colab please follow the pictures :) below.
#
# ## Step 1 - Save a copy in Drive
# This action will save a copy of the Notebook in YOUR Google Drive > Colab notebooks folder.
#
# **You have to be registered/logged in your Google acount**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Step -2 Rename your Notebook

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Step - 3 Run code cells to activate Python code for this session

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# That's it. You can now edit this Notebook according to your desire.

# %% [markdown]
# # Resources
#
# ## Colab Jupyter Notebooks
# * [Mapping Geo Data with Wikipedia](https://colab.research.google.com/drive/1Hs6kxf2x_o8A-1j2SXJHGM6lIeIxpbMr?authuser=1#scrollTo=86lvw0RYtXx6)
#
#
# ## Main tools
# * https://colab.research.google.com/
# * https://spacy.io/
#
# ## Distant reading
# * https://github.com/distantreading
# ### NER Workshop
# * https://github.com/distantreading/WG2/tree/master/NER_TS
# * https://github.com/distantreading/WG2/tree/master/NER_TS/TXT_samples
# https://github.com/distantreading/WG2/tree/master/NER_TS/novels
#
#
# ### Additional resources
# * Pandas https://pandas.pydata.org/
# * igraph https://igraph.org/python/
# * Plotly https://plotly.github.io/plotly.py-docs/index.html#
# * Time module https://docs.python.org/3/library/time.html

# %% [markdown]
# # Data Table Display by Google
# Colab includes an extension that renders pandas dataframes into interactive displays that can be filtered, sorted, and explored dynamically.
#
# Data table display for Pandas dataframes can be enabled by running:
# ```python
# %load_ext google.colab.data_table
# ```
# and disabled by running
# ```python
# %unload_ext google.colab.data_table
# ```

# %%
# %load_ext google.colab.data_table
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
# import spacy
# process text
# get geo NER
# extract information about NER
# represent using the folium

# %%
import time

# %% [markdown]
# # Corpus creation by using NLP pipelines
# Digitally tagged corpuses are produced using NLP algorithms based on machine learning algorithms. The method is to build a pipeline of several sequential processing components and add information layer, ie. tagg,  on a sequence of characters, ie. text.
#
# The idea is to break up text analysis problems into very small pieces and then use machine learning to solve each smaller task separately. Then, by chaining together several machine learning models that feed into each other, you can do very complicated things. (See more: [Suneel Patel](https://medium.com/@suneelpatel.in/nlp-pipeline-building-an-nlp-pipeline-step-by-step-7f0576e11d08))
#
# ![pipeline.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## NLP tasks
# 1. **Information retrieval**.
# Finds documents of text that satisfies an information need from within large collections
# 2. **Named entity recognition**.
# Seeks to locate and classify entities into predefined categories such as person names, organizations, locations, medical codes, time expressions, quantities, monetary values, percentages, etc.
# 3. **Relation extraction**.
# Extracts semantic relationships from the text, which usually occur between two or more entities
# 4. **Text classification/Document Classification**.
# Assigns a text/document to one or more classes or categories.
# 5. **Document Ranking**
# 6. **Annotation**
# 7. **Topic modelling**
# Discovers the abstract “topics” that occur in a collection of documents
# 8. **Keyword Extraction**
# 9. **Machine translation**
# 10. **Parts of speech tagging**.
# Process of marking up a word in a text as corresponding to a particular part of speech
# 11. **Semantic Role Labeling**.
# Indicates the semantic role in the sentence, such as that of an agent, goal, or result
# 12. **Word Sense Disambiguation**.
# Identifies which sense of a word is used in a sentence
# 13. **Grammatical Error Correction**
# 14. **Semantic textual similarity**.
# determines how similar two pieces of texts are. This can take the form of assigning a score from 1 to 5. Related tasks are paraphrase or duplicate identification.
# 15. **Text summarization/Meeting Summarization**
# 16. **Reading comprehension**
# 17. **Question and answering**
# 18. **Question Generation**
# 19. **Image captioning**
# 20. **Fake News Detection/Hate Speech Detection**
# 21. **Text generation**
# 22. **Sentiment/emotion analysis**.
# Interprets and classifies of emotions (positive, negative and neutral) with text data
# 23. **Speech-to-text**.
# Translation of spoken language into text
# 24. **Text-to-speech**.
# Converts text into spoken voice output
# 25. **Dialogue Understanding**
#
# More about  [State of the art (SOTA) NLP tasks](https://paperswithcode.com/area/natural-language-processing), [Medium article by Jayathilaka](https://medium.com/@miranthaj/25-nlp-tasks-at-a-glance-52e3fdff32e2),

# %% [markdown]
# # Various pipelines
# There are diferent types of NLP pipelines (see [Castilho and Gurevych 2014](https://www.aclweb.org/anthology/W14-5201.pdf)). The difference is conditioned by multiple reasons.
#
# - *Availability of language specific tools and resources*. One of key constraints is the availability / scarcity of the tools and resources in a language (see repositories: [Sebastianruder *Tracking Progress in Natural Language Processing* ](https://github.com/sebastianruder/NLP-progress), [Stanford NLP group](https://github.com/stanfordnlp/stanza),  [Classla-Stanford for Slavic languages](https://github.com/clarinsi/classla-stanfordnlp), ...). Of course, the more economically dominant a language community, the more linguistic resources.
#
# - *Difference in methods and approaches.* Due to the vast number of approaches, there is overwhelming number of different methods and computational programs used to process the text (see [Keon's *awesome-nlp* repository](https://github.com/keon/awesome-nlp)).
#
# - *Goal of the application*. According to the final goal of the text analysis, the applications can use all or some of the components available at the processing pipeline.
#
# ![nlppipeline.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Spacy
# Spacy is 'industrial-strength Natural Language Processing' package for Python. See more at https://spacy.io/
# ![spacy.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Spacy 101
# * https://spacy.io/usage/spacy-101

# %% [markdown]
# # Language models
# spaCy’s trained pipelines can be installed as Python packages. This means that they’re a component of your application, just like any other module. They’re versioned and can be defined as a dependency in your requirements.txt. Trained pipelines can be installed from a download URL or a local directory, manually or via pip. Their data can be located anywhere on your file system.
#
# * https://spacy.io/usage/models

# %% [markdown]
# ## Example using Spacy library
#
# 1) Define text

# %%
cnn_text ="""
CNN) — Once one of the world's most powerful travel documents, the might of the US passport has shriveled during the Covid-19 pandemic. With US coronavirus cases over the 11.4 million mark and climbing rapidly, many nations continue to view America with trepidation.
The European Union has omitted the United States from its list of countries whose tourists may visit. Americans still can't vacation in their neighbor to the north, Canada, nor head to many Asian favorites such as Japan.
While most US travelers are staying close to home, some still want to go abroad. For those people, there are still popular vacation options such as Mexico, Ireland and South Korea.
Whether travel to open international destinations is responsible or advisable is up to you. Remember that rules can change at any time. Rules' violations might involve stiff fines or even jail time. The US Centers for Disease Control and Prevention and the US State Department provide Covid-19 risk assessments by country.
What follows is a list of countries, in alphabetical order, where it's still possible for US passport holders to go for a vacation:
Albania
UPDATE: Set on the gorgeous Adriatic Sea, Albania is open. However, key airlines have canceled or curtailed flights into December. The US Embassy website states that while there's no Covid-19 test requirements or quarantine, you can expect a health screening.
Anguilla
This British territory in the Caribbean is accepting international visitors. You must be pre-approved; click here to start the process and read up on extensive Covid-19 testing requirements. The United States is considered a high-risk nation by most places, so Americans might be far down the list.
"""

# %% [markdown]
# 2) Install, import Spacy, load language model, store the nlp parsing in a doc object, parse the doc object

# %%
# install spaCy
# !pip install spacy

# %%
# download a model
# !python -m spacy download en_core_web_sm
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# importing spaCy in the memory
import spacy

# %%
start= time.time()
# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

# Process text 
doc = nlp(cnn_text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_, entity.start)


end=time.time()-start
print('Text processed in ', end, 'seconds.')
# Out:
# Noun phrases: ['\nCNN', "the world's most powerful travel documents", 'the might', 'the US passport', 'the Covid-19 pandemic', 'US coronavirus cases', 'the 11.4 million mark', 'many nations', 'America', 'trepidation', 'The European Union', 'the United States', 'its list', 'countries', 'whose tourists', 'Americans', 'their neighbor', 'the north', 'Canada', 'head', 'many Asian favorites', 'Japan', 'most US travelers', 'home', 'those people', 'popular vacation options', 'Mexico', 'Ireland', 'South Korea', 'international destinations', 'you', 'rules', 'any time', "Rules' violations", 'stiff fines', 'even jail time', 'The US Centers', 'Disease Control', 'Prevention', 'the US State Department', 'Covid-19 risk assessments', 'country', 'What', 'a list', 'countries', 'alphabetical order', 'it', 'US passport holders', 'a vacation', 'Albania', 'the gorgeous Adriatic Sea', 'Albania', 'key airlines', 'flights', 'December', 'The US Embassy website', 'no Covid-19 test requirements', 'quarantine', '
# ...

# %% [markdown]
# # Named Entities with spaCy
# * https://spacy.io/usage/linguistic-features#named-entities
#
# spaCy features an extremely fast statistical entity recognition system, that assigns labels to contiguous spans of tokens. The default trained pipelines can indentify a variety of named and numeric entities, including **companies, locations, organizations** and **products**. You can add arbitrary classes to the entity recognition system, and update the model with new examples.

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %% [markdown]
# ## Represent the NE using displaCy
# Using the `displacy.render` method we can visualize the Named Entities.
#
# * https://spacy.io/usage/visualizers

# %%
from spacy import displacy
text = "When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him seriously. Only few people in Alabama."
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
# using the displacy render method we can visualize the Named Entities
displacy.render(doc, style='ent', jupyter=True, options={'distance': 80})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sebastian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Thrun started working on self-driving cars at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
# ...

# %% [markdown]
# # Importing text
# * [Working with Text Files in Colab Notebooks](https://www.youtube.com/watch?v=mKP7ChzJBqg) video and [colab](https://colab.research.google.com/drive/1XUyt9P_DMY2JnKZLvwvX5lVXnZZhiZtW?usp=sharing) by Zach Whalen

# %% [markdown]
# ### Texts from Github repository for the Workshop
# * https://github.com/distantreading/WG2/tree/master/NER_TS/novels

# %%
# variable = linkToFile
BleakHouse='https://raw.githubusercontent.com/distantreading/WG2/master/NER_TS/novels/BleakHouse.txt'
GreatExpectations='https://raw.githubusercontent.com/distantreading/WG2/master/NER_TS/novels/GreatEXpectations.txt'
JaneEyre='https://raw.githubusercontent.com/distantreading/WG2/master/NER_TS/novels/JaneEyre.txt'
OliverTwist='https://raw.githubusercontent.com/distantreading/WG2/master/NER_TS/novels/OliverTwist.txt'

# %%
# some more texts
AroundTheWorld= 'https://www.gutenberg.org/cache/epub/103/pg103.txt'

# %% [markdown]
# #### Task - import a text from github repository
# Add link to  David Copperfield **raw** txt file as a DavidCopperfield variable from https://github.com/distantreading/WG2/tree/master/NER_TS/novels

# %%
# Add link to David Copperfield raw txt as a DavidCopperfield variable

# %% [markdown]
# ## Importing text using `requests` library
# * https://requests.readthedocs.io/en/master/

# %%
import requests
# Loading a text from a link
text_link = AroundTheWorld# OliverTwist
result = requests.get(text_link)
text = result.text

# %% [markdown]
# ## Simple token count using `split()` and `len()` functions.

# %%
# count how many characters, tokens
numberOfCharacters = len(text)
numberOfTokens= len(text.split())
print( 'Text has '+str(numberOfCharacters)+' characters and '+str(numberOfTokens)+' tokens.')
# Out:
# Text has 398638 characters and 66313 tokens.

# %% [markdown]
# ## Print first few 10000 characters

# %%
# print the first 10 000 characters of the text
print(text[0:1000])
# Out:
# ﻿The Project Gutenberg EBook of Around the World in 80 Days, by Jules Verne
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# Title: Around the World in 80 Days
#
# Author: Jules Verne
#
# Release Date: May 15, 2008 [EBook #103]
# Last updated: February 18, 2012
# Last updated: May 5, 2012
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK AROUND THE WORLD IN 80 DAYS ***
#
#
#
#
#
#
#
#
#
#
#
#
#
# AROUND THE WORLD IN EIGHTY DAYS
#
#
#
# CONTENTS
#
#
# CHAPTER
#
#       I  IN WHICH PHILEAS FOGG AND PASSEPARTOUT ACCEPT EACH OTHER, THE
#          ONE AS MASTER, THE OTHER AS MAN
#
#      II  IN WHICH PASSEPARTOUT IS CONVINCED THAT HE HAS AT LAST FOUND
#          HIS IDEAL
#
#     III  IN WHICH A CONVERSATION TAKES PLACE WHICH SEEMS LIKELY TO COST
# ...

# %% [markdown]
# # Processing the `text` into spaCy `doc` object

# %%
#measure time
start= time.time()
# process the whole text
nlp.max_length = 1021734 #or any large value, as long as you don't run out of RAM
doc = nlp(text)
# return the time necessary for processing (just for a reference)
end=time.time()-start
print('Processed text:', text, ' in', end, 'seconds.')
# Out:
# Processed text: ﻿The Project Gutenberg EBook of Around the World in 80 Days, by Jules Verne
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# Title: Around the World in 80 Days
#
# Author: Jules Verne
#
# Release Date: May 15, 2008 [EBook #103]
# Last updated: February 18, 2012
# Last updated: May 5, 2012
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK AROUND THE WORLD IN 80 DAYS ***
#
#
#
#
#
#
#
#
#
#
#
#
#
# AROUND THE WORLD IN EIGHTY DAYS
#
#
#
# CONTENTS
#
#
# CHAPTER
#
#       I  IN WHICH PHILEAS FOGG AND PASSEPARTOUT ACCEPT EACH OTHER, THE
#          ONE AS MASTER, THE OTHER AS MAN
#
#      II  IN WHICH PASSEPARTOUT IS CONVINCED THAT HE HAS AT LAST FOUND
#          HIS IDEAL
#
# ...

# %% [markdown]
# # spaCy Language Processing Pipeline
# When you call nlp on a text, spaCy first tokenizes the text to produce a Doc object. The Doc is then processed in several different steps – this is also referred to as the processing pipeline. The pipeline used by the trained pipelines typically include a tagger, a lemmatizer, a parser and an entity recognizer. Each pipeline component returns the processed Doc, which is then passed on to the next component.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Doc object
# `Doc` object is a sequence of `Token` objects. Access sentences and named entities, export annotations to numpy arrays, losslessly serialize to compressed binary strings. The Doc object holds an array of TokenC structs. The Python-level Token and Span objects are views of this array, i.e. they don’t own the data themselves.
#
# * https://spacy.io/api/doc
#
# # Linguistic features of spaCy
#
# * https://spacy.io/usage/linguistic-features
#
# Processing raw text intelligently is difficult: most words are rare, and it’s common for words that look completely different to mean almost the same thing. The same words in a different order can mean something completely different. Even splitting text into useful word-like units can be difficult in many languages. While it’s possible to solve some problems starting from only the raw characters, it’s usually better to use linguistic knowledge to add useful information. That’s exactly what spaCy is designed to do: you put in raw text, and get back a Doc object, that comes with a variety of annotations.
#
#
# ## Tokens
# Linguistic annotations are available as Token attributes. Like many NLP libraries, spaCy encodes all strings to hash values to reduce memory usage and improve efficiency. So to get the readable string representation of an attribute, we need to add an underscore _ to its name:
#
#
# ## Part-of-speech tagging
# * https://spacy.io/usage/linguistic-features#pos-tagging
#
# After tokenization, spaCy can parse and tag a given Doc. This is where the trained pipeline and its statistical models come in, which enable spaCy to make predictions of which tag or label most likely applies in this context. A trained component includes binary data that is produced by showing a system enough examples for it to make predictions that generalize across the language – for example, a word following “the” in English is most likely a noun.
#
# ## Lemmatization
# * https://spacy.io/usage/linguistic-features#lemmatization
#
# The Lemmatizer is a pipeline component that provides lookup and rule-based lemmatization methods in a configurable component. An individual language can extend the Lemmatizer as part of its language data.
#
# ## Dependency Parsing
# * https://spacy.io/usage/linguistic-features#dependency-parse
# spaCy features a fast and accurate syntactic dependency parser, and has a rich API for navigating the tree. The parser also powers the sentence boundary detection, and lets you iterate over base noun phrases, or “chunks”. You can check whether a Doc object has been parsed by calling doc.has_annotation("DEP"), which checks whether the attribute Token.dep has been set returns a boolean value. If the result is False, the default sentence iterator will raise an exception.
#
# ## Named Entity
# * https://spacy.io/usage/linguistic-features#named-entities
#
# A named entity is a “real-world object” that’s assigned a name – for example, a person, a country, a product or a book title. spaCy can recognize various types of named entities in a document, by asking the model for a prediction. Because models are statistical and strongly depend on the examples they were trained on, this doesn’t always work perfectly and might need some tuning later, depending on your use case.
#
# Named entities are available as the ents property of a `Doc`
#
#
# * https://spacy.io/usage/linguistic-features#accessing-ner
#
#
#
# ## Sentence Segmentation
# * https://spacy.io/usage/linguistic-features#sbd
# A Doc object’s sentences are available via the `Doc.sents` property. To view a Doc’s sentences, you can iterate over the Doc.sents, a generator that yields Span objects. You can check whether a Doc has sentence boundaries by calling Doc.has_annotation with the attribute name "SENT_START".

# %% [markdown]
# # Create a dictionary with NLP parsed token features of a doc object

# %%
# for each token in the doc object
# "token", "lemma", "POS", "conjuncts", "tag", "dep", "head", "head_i",  "ent._label_"
#  in the doc and store token key:value pairs in a dictionary
doc_dict = []
for t in doc:
  entity = {"token": t.text, "lemma": t.lemma_, "POS": t.pos_, "conjuncts": t.conjuncts, "tag": t.tag_, "dep": t.dep_, "head": t.head, "head_i": t.head.i, "ent._iob_": t.ent_iob_, "ent._type_": t.ent_type_}
  doc_dict.append(entity)
# doc_dict
doc_dict
# Out:
# [{'POS': 'PROPN',
#   'conjuncts': (),
#   'dep': 'ROOT',
#   'ent._iob_': 'O',
#   'ent._type_': '',
#   'head': ﻿The,
#   'head_i': 0,
#   'lemma': '\ufeffThe',
#   'tag': 'NNP',
#   'token': '\ufeffThe'},
#  {'POS': 'PROPN',
#   'conjuncts': (),
#   'dep': 'compound',
#   'ent._iob_': 'O',
#   'ent._type_': '',
#   'head': Gutenberg,
#   'head_i': 2,
#   'lemma': 'Project',
#   'tag': 'NNP',
#   'token': 'Project'},
#  {'POS': 'PROPN',
#   'conjuncts': (),
#   'dep': 'ROOT',
#   'ent._iob_': 'B',
#   'ent._type_': 'PERSON',
#   'head': Gutenberg,
#   'head_i': 2,
#   'lemma': 'Gutenberg',
#   'tag': 'NNP',
#   'token': 'Gutenberg'},
#  {'POS': 'PROPN',
#   'conjuncts': (),
#   'dep': 'appos',
#   'ent._iob_': 'I',
#   'ent._type_': 'PERSON',
#   'head': Gutenberg,
#   'head_i': 2,
#   'lemma': 'EBook',
#   'tag': 'NNP',
#   'token': 'EBook'},
#  {'POS': 'ADP',
#   'conjuncts': (),
#   'dep': 'prep',
#   'ent._iob_': 'O',
#   'ent._type_': '',
#   'head': EBook,
#   'head_i': 3,
# ...

# %% [markdown]
# # DataFrame representation of the parsed document
# DataFrame is a convenient type of representing and manipulating data.
# * https://pandas.pydata.org
# * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %%
# importing pandas
import pandas as pd

# %% [markdown]
# ## Representing a dictionary object as a Pandas dataFrame

# %%
df_doc = pd.DataFrame().from_dict(doc_dict)
# represent first 500 tokens
df_doc[0:500]
# Out:
#          token      lemma    POS  ... head_i ent._iob_ ent._type_
# 0         ﻿The       ﻿The  PROPN  ...      0         O
# 1      Project    Project  PROPN  ...      2         O
# 2    Gutenberg  Gutenberg  PROPN  ...      2         B     PERSON
# 3        EBook      EBook  PROPN  ...      2         I     PERSON
# 4           of         of    ADP  ...      3         O
# ..         ...        ...    ...  ...    ...       ...        ...
# 495         IN         in    ADP  ...    498         O
# 496      WHICH      which    DET  ...    495         O
# 497        FIX        fix   NOUN  ...    498         O
# 498      COMES       come   VERB  ...    498         O
# 499       FACE       face   NOUN  ...    498         O
#
# [500 rows x 10 columns]

# %% [markdown]
# # Descriptive statistics on Named Entities

# %%
# unique type of entities in the doc
ent_unique= df_doc['ent._type_'].unique()
ent_unique
# Out:
# array(['', 'PERSON', 'DATE', 'ORG', 'CARDINAL', 'LANGUAGE', 'GPE',
#        'WORK_OF_ART', 'PRODUCT', 'NORP', 'FAC', 'QUANTITY', 'ORDINAL',
#        'TIME', 'LOC', 'MONEY', 'EVENT', 'LAW', 'PERCENT'], dtype=object)

# %%
# Count of entity types
entities= df_doc.groupby('ent._type_').count()[1:]['lemma'].sort_values(ascending=False)
entities
# Out:
# ent._type_
# ORG            1371
# PERSON         1266
# TIME            959
# DATE            940
# GPE             884
# CARDINAL        565
# QUANTITY        443
# LOC             314
# NORP            264
# WORK_OF_ART     186
# FAC             163
# ORDINAL          75
# MONEY            64
# LANGUAGE         41
# PRODUCT          36
# EVENT            20
# LAW              18
# PERCENT           2
# Name: lemma, dtype: int64

# %%
# Visualise the Entities as horizontal barplot
df_doc.groupby('ent._type_').count()[1:]['lemma'].sort_values().plot.barh()

# %%
# Percentage of the Entity types in overall Entites
ent_types = df_doc.groupby('ent._type_').count()['lemma']
(ent_types/ent_types[1:].sum()*100).sort_values(ascending=False)[1:]
# Out:
# ent._type_
# ORG            18.013402
# PERSON         16.633819
# TIME           12.600184
# DATE           12.350545
# GPE            11.614768
# CARDINAL        7.423466
# QUANTITY        5.820523
# LOC             4.125608
# NORP            3.468664
# WORK_OF_ART     2.443831
# FAC             2.141637
# ORDINAL         0.985416
# MONEY           0.840888
# LANGUAGE        0.538694
# PRODUCT         0.473000
# EVENT           0.262778
# LAW             0.236500
# PERCENT         0.026278
# Name: lemma, dtype: float64

# %%
df_doc.groupby('ent._type_').count()[1:]['lemma'].sort_values().plot.pie()

# %% [markdown]
# ## Representation of a type of Entities

# %%
#@title Unique  x Entities
dropdown = 'PERSON' #@param ['PERSON', 'ORG', 'GPE', 'CARDINAL', 'DATE', 'ORDINAL','WORK_OF_ART', 'LOC', 'NORP', 'TIME', 'PRODUCT', 'FAC', 'EVENT', 'MONEY', 'QUANTITY', 'LAW', 'LANGUAGE']
print(dropdown)

entity_type= dropdown
print(df_doc[df_doc['ent._type_']== entity_type]['lemma'].unique())
len(df_doc[df_doc['ent._type_']== entity_type]['lemma'].unique())
# Out:
# PERSON
# ['Gutenberg' 'EBook' 'Jules' 'Verne' 'FOGG' 'Phileas' 'Fogg' 'Byron' 'the'
#  'Queen' "'s" 'Bench' 'Barings' '\r\n' 'James' 'Forster' 'Saville' 'Row'
#  'Jean' 'Blondin' 'Monsieur' 'chapter' 'II' '\r\n\r\n' 'Tussaud' 'calm'
#  'Angelica' 'Kauffmann' 'Moliere' 'Minerva' 'Longferry' 'Haymarket'
#  'Sheridan' 'joyfully' 'Andrew' 'Stuart' 'John' 'Sullivan' 'Samuel'
#  'Fallentin' 'Thomas' 'Flanagan' 'Gauthier' 'Ralph' 'Allahabad' 'Calcutta'
#  'Bradshaw' 'article' 'Albemarle' 'Rowan' 'Brindisi' 'M.' 'Lesseps' 'Fix'
#  'Mont' 'Cenis' 'Left' 'Turin' 'Bab' '-' 'el' 'Mandeb' 'Goa' 'Decimus'
#  'Smith' 'Passepartout' 'Mocha' 'Solomon' 'Burdivan' 'Mew' 'Zoroaster'
#  'Parsee' 'Francis' 'Cromarty' 'Callyan' 'Pauwell' 'picturesque'
#  'bungalow' 'viharis' 'Milligaum' 'Kali' 'Ellora' 'Nizam' 'Feringhea'
#  'Thuggee' 'Kholby' 'zebus' 'impart' 'happily' 'Kiouni' 'Vindhias' 'a'
#  'Aouda' 'Pillaji' 'Jumna' 'Ramayana' 'Ucaf' 'Uddaul' 'Kama' 'Casi'
# ...

# %%
#@title Selecting the dataset by an Entity type 
dropdown = 'ORG' #@param ['PERSON', 'ORG', 'GPE', 'CARDINAL', 'DATE', 'ORDINAL','WORK_OF_ART', 'LOC', 'NORP', 'TIME', 'PRODUCT', 'FAC', 'EVENT', 'MONEY', 'QUANTITY', 'LAW', 'LANGUAGE']
print(dropdown)
df_doc[df_doc['ent._type_']==dropdown]
# Out:
# ORG
#             token       lemma    POS  ... head_i ent._iob_ ent._type_
# 17          eBook       eBook  PROPN  ...     18         B        ORG
# 63          eBook       ebook   NOUN  ...     61         B        ORG
# 240            IN          in    ADP  ...    247         B        ORG
# 241         WHICH       WHICH  PROPN  ...    242         I        ORG
# 242           FIX         FIX  PROPN  ...    247         I        ORG
# ...           ...         ...    ...  ...    ...       ...        ...
# 89350        \r\n        \r\n  SPACE  ...  89349         I        ORG
# 89351     Archive     Archive  PROPN  ...  89352         I        ORG
# 89352  Foundation  Foundation  PROPN  ...  89345         I        ORG
# 89360      eBooks      eBooks  PROPN  ...  89357         B        ORG
# 89375      eBooks      eBooks  PROPN  ...  89373         B        ORG
#
# [1371 rows x 10 columns]

# %%
# Selecting a set of lemmas
df_doc[df_doc['lemma']=='Birmingham']
# Out:
#             token       lemma    POS  ... head_i ent._iob_ ent._type_
# 29552  Birmingham  Birmingham  PROPN  ...  29550         B        GPE
#
# [1 rows x 10 columns]

# %% [markdown]
# ## Key word in context search

# %%
# A simple KWIC search by lemma
search_lemma='London'
indexed = df_doc[df_doc['lemma']==search_lemma].index
distance=10
n=0
for occ in indexed:
  n=n+1
  print(n, occ, ' '.join(df_doc.iloc[occ-distance:occ+distance]['token']).replace('\n','')+'\n')
# Out:
#  which he was the owner ;
#
#  Institution , the Artisan 's Association , or
#
#  London for many years .   Those who were honoured
#
#  visited in London ; speech is all that is wanting to make
#
#  who arrived at or left London by rail , and a judicial examination was
#
#      Brindisi ,
#
#    From New York to London , by steamer and rail ........ 9   "
#
#  October , I shall be due in London in this very room of the Reform Club ,
#
#  "
#
#  create a lively sensation at the West
#
#  Illustrated London News came out with his portrait , copied from
#
#  Rowan , Commissioner of Police , Scotland
#
#  London .   The detective was evidently inspired by the
#
#  This observation
#
#  the New World , he
#
#  " Ah , that 's your
#
#  "
#
#  " Left London , Wednesday , October 2nd , at 8.45 p.m.
#
#  New York , and London -- from the 2nd of October to the 21st
#
#  hours behind that
#
#  " I
#
#  The effect of these replies upon
#
#  the robbery ; the large sum
#
# ...

# %%
# An entity representation KWIC search by lemma
search_lemma='London'
distance=10
df_doc= df_doc[df_doc.POS != 'SPACE']
indexed = df_doc[df_doc['lemma']==search_lemma].index
for occ in indexed:
  try:
    span = doc[(occ-distance):(occ+distance)]
    displacy.render(span, style='ent', jupyter=True, options={'distance': 80})
  except ValueError:
    pass
  except:
    span = doc[(occ-distance+4):(occ+distance+5)]
    displacy.render(span, style='ent', jupyter=True, options={'distance': 80})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the &quot;City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot;; no ships ever came into
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  docks of
# which he was the owner; </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">in the sage deliberations of
# ...

# %% [markdown]
# # Reclassifying entities
# Obviously, there are lots of poorely classified types of entities.
#
# This session can not go into the retraining, but there are several options how to approach the problem.
# * https://spacy.io/usage/training
#
# ![image.png](data:image/png;base64,...)
#
#
# * https://spacy.io/usage/layers-architectures#components
# * Prodigy https://prodi.gy/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Creating a graph from coocuring Named Entities
#
# Pseudo code:
# ```
# # for an entity eS, find all entities eF within a distance
# # store e1, e1F1....e1Fx in a list of tuple representation listTuple= [(e1, e1F1), (e1F2)....]
# # create a graph from tuples
# ```

# %% [markdown]
# * https://igraph.org/python/
# * https://networkx.org/
# * [Graph Theory](https://books.google.hr/books?hl=en&lr=&id=LJPSDwAAQBAJ&oi=fnd&pg=PR9&dq=graph+theory&ots=Hsp2OJi6GT&sig=9F3IPSp4czP4iPT-0ESYLmBsJ98&redir_esc=y#v=onepage&q=graph%20theory&f=false)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Step-1 Select what type of entities would you like to get in the coocurence network
#
# In this section you can select:
# * what type of ENTITIES would you like to find in coocurences.
# * what is the word distance between source ENTITY and collocated ENTITIES

# %%
#select what type of Entites would you like to get into network
# ['PERSON', 'DATE', 'ORG', 'CARDINAL', 'LANGUAGE', 'GPE', 'WORK_OF_ART', 'PRODUCT', 'NORP', 'FAC', 'QUANTITY', 'ORDINAL', 'TIME', 'LOC', 'MONEY', 'EVENT', 'LAW', 'PERCENT']
options = ["PERSON"] 
#select distance from the NE for creating a span
distance=20

# %% [markdown]
# ## Step 2- Extract the coocurences

# %%
t_start=time.time()
# store entities in the list
e=[]
eF=[]
# distance between source and collocation entity

for ent in doc.ents:
  if ent.label_ in options: 
    entity = {'text':ent.text, 'label': ent.label_, 'start': ent.start} 
    # find span
    span = doc[(entity['start']-distance):(entity['start']+distance)]
    # find surrounding entities in span
    for entF in span.ents:
      if entF.label_ in options:
        entityF = {'text':entF.text, 'label': entF.label_, 'start': entF.start}
        # do not capture self referring tuples
        if entity != entityF:
          e_eF_t= (entity, entityF)
          eF.append(e_eF_t) 

#print first 20 tuples
print(eF[0:20])

print(len(eF), '(source-friend) tuples in a span +/-', distance, 'processed in', time.time()-t_start, 'seconds')
# Out:
# [({'text': 'Phileas Fogg', 'label': 'PERSON', 'start': 2285}, {'text': 'Jean', 'label': 'PERSON', 'start': 2299}), ({'text': 'Jean', 'label': 'PERSON', 'start': 2299}, {'text': 'Phileas Fogg', 'label': 'PERSON', 'start': 2285}), ({'text': 'Calm', 'label': 'PERSON', 'start': 2936}, {'text': 'Fogg', 'label': 'PERSON', 'start': 2947}), ({'text': 'Fogg', 'label': 'PERSON', 'start': 2947}, {'text': 'Calm', 'label': 'PERSON', 'start': 2936}), ({'text': 'Fogg', 'label': 'PERSON', 'start': 2947}, {'text': 'Angelica Kauffmann', 'label': 'PERSON', 'start': 2958}), ({'text': 'Angelica Kauffmann', 'label': 'PERSON', 'start': 2958}, {'text': 'Fogg', 'label': 'PERSON', 'start': 2947}), ({'text': 'Longferry', 'label': 'PERSON', 'start': 3529}, {'text': 'Haymarket', 'label': 'PERSON', 'start': 3542}), ({'text': 'Haymarket', 'label': 'PERSON', 'start': 3542}, {'text': 'Longferry', 'label': 'PERSON', 'start': 3529}), ({'text': 'Andrew Stuart', 'label': 'PERSON', 'start': 4617}, {'text': 'John\r\nSulli
# ...

# %% [markdown]
# ## Step-3 Prepare data for a graph type object
# * nodes have to be unique
# * relations have to reflect the source-friend connection along with calculated weight

# %%
eF_df= pd.DataFrame()
eF_df['Source']       = [x[0]['text'] for x in eF]
eF_df['Source_label'] = [x[0]['label'] for x in eF]
eF_df['Source_start'] = [x[0]['start'] for x in eF]
eF_df['Friend']       = [x[1]['text'] for x in eF]
eF_df['Friend_label'] = [x[1]['label'] for x in eF]
eF_df['Friend_start'] = [x[1]['start'] for x in eF]
# create a weight value that reflects the closer the higher value as 1/abs(start_Source- start_Friend)
eF_df['weight'] = [1/abs(x[0]['start']-x[1]['start']) for x in eF]

# fix for duplicate nodes occuring due to the special characters
eF_df['Source']=eF_df['Source'].str.replace('\r','').str.replace('\n', '')
eF_df['Friend']=eF_df['Friend'].str.replace('\r','').str.replace('\n', '')

# print the eF_df dataframe object
eF_df
# Out:
#                      Source Source_label  ...  Friend_start    weight
# 0              Phileas Fogg       PERSON  ...          2299  0.071429
# 1                      Jean       PERSON  ...          2285  0.071429
# 2                      Calm       PERSON  ...          2947  0.090909
# 3                      Fogg       PERSON  ...          2936  0.090909
# 4                      Fogg       PERSON  ...          2958  0.090909
# ..                      ...          ...  ...           ...       ...
# 485    Project Gutenberg-tm       PERSON  ...         88477  0.250000
# 486  Project Gutenberg-tm's       PERSON  ...         88541  0.055556
# 487                  eBooks       PERSON  ...         89315  0.066667
# 488                     Web       PERSON  ...         89300  0.066667
# 489    Project Gutenberg-tm       PERSON  ...         89315  0.052632
#
# [490 rows x 7 columns]

# %% [markdown]
# ## Step -4 Create a graph from coocurring entities
#
# In this section we will convert the data into a graph structure (source)--(friend) using igraph
# * https://igraph.org/python/
#
# This will allow us to extract graph based insights for the data.

# %%
# !pip install python-igraph

# %%
import igraph
print(igraph.__version__)
# Out:
# 0.9.0

# %%
from plotly.offline import plot
import plotly.graph_objs as go
import plotly.io as pio
import plotly.express as px
import math
import numpy as np

# %%
# activate graph object
g = igraph.Graph()
type(g)
# Out:
# igraph.Graph

# %%
# Create unique list of Nodes names relative to the different ent_type
# merge Source and Friend into nodes
nodes_source= eF_df[['Source', 'Source_label']]
nodes_source.columns=['name', 'ent_type']
nodes_friends = eF_df[['Friend', 'Friend_label']]
nodes_friends.columns=['name', 'ent_type']
nodes= nodes_source.append(nodes_friends)
# nodes['name']= nodes['name'].str.replace('\r','').str.replace('\n', '')

# group by 'name' and 'ent_type'. reset index to get a dataframe
nodes_unique = nodes.groupby(['name', 'ent_type']).count().reset_index()
nodes_unique
# Out:
#                       name ent_type
# 0                Allahabad   PERSON
# 1                     Anam   PERSON
# 2            Andrew Speedy   PERSON
# 3            Andrew Stuart   PERSON
# 4       Angelica Kauffmann   PERSON
# ..                     ...      ...
# 110                 eBooks   PERSON
# 111          mummy showman   PERSON
# 112  picturesque bungalows   PERSON
# 113                viharis   PERSON
# 114                  zebus   PERSON
#
# [115 rows x 2 columns]

# %% [markdown]
# ## Step - 5 Creating nodes and relations including node and relation properties from graph

# %%
# add nodes from unique set of nodes
for index, row in nodes_unique.iterrows():
  g.add_vertex(row['name'], ent_type = row.ent_type)

# %%
# add relations from eF_df dataframe and weight
for index, row in eF_df.iterrows():  
  g.add_edge(row['Source'], row['Friend'], weight=row.weight)
#print(g)

# %%
g= g.simplify(combine_edges=max)
g.vs["label"]= g.vs["name"]
g.vs["degree"]=g.vs.degree()
g.vs['betweenness'] = g.betweenness(vertices=None, directed=False, cutoff=None, weights=None, nobigint=True)
g.vs["pagerank"]=g.vs.pagerank(directed=False, weights='weight')
print(g)
# Out:
# IGRAPH UNW- 115 142 --
# + attr: betweenness (v), degree (v), ent_type (v), label (v), name (v),
#   pagerank (v), weight (e)
# + edges (vertex names):
# Allahabad--Fogg, Allahabad--Francis, Allahabad--John Sullivan, Anam--Rangoon,
# Andrew Speedy--Fogg, Andrew Speedy--Phileas Fogg, Andrew Stuart--Gauthier
# Ralph, Andrew Stuart--John Sullivan, Andrew Stuart--JohnSullivan, Andrew
# Stuart--Samuel Fallentin, Andrew Stuart--Thomas Flanagan, Angelica
# Kauffmann--Fogg, Aouda--Camerfield, Aouda--Fix, Aouda--Fogg, Aouda--Francis,
# Aouda--Francis Cromarty, Aouda--Frenchman, Aouda--Jametsee Jeejeebhoy,
# Aouda--Jeejeeh, Aouda--John Bull, Aouda--Mandiboy, Aouda--Mr.--Mr,
# Aouda--Passepartout, Aouda--Phileas Fogg, Aouda--Proctor,
# Bab-el-Mandeb--Phileas Fogg, Barings--Fogg, Boots--Fogg, Bradshaw--Fogg,
# Brahma--Shiva, Brahmins--Shiva, Burdivan--Calcutta, Buxar--Patna,
# Calcutta--Fogg, Calcutta--Francis, Calcutta--Obadiah, Calcutta--Phileas Fogg,
# ...

# %%
nodesProperties= {'name':g.vs["name"], 'ent_type':g.vs['ent_type'], 'degree':g.vs["degree"], 'pagerank':g.vs["pagerank"], 'betweenness': g.vs['betweenness'] }
nodes_df= pd.DataFrame().from_dict(nodesProperties)
nodes_df
# Out:
#                       name ent_type  degree  pagerank  betweenness
# 0                Allahabad   PERSON       3  0.014108    29.345238
# 1                     Anam   PERSON       1  0.003988     0.000000
# 2            Andrew Speedy   PERSON       2  0.004732     0.000000
# 3            Andrew Stuart   PERSON       5  0.010264     1.000000
# 4       Angelica Kauffmann   PERSON       1  0.002872     0.000000
# ..                     ...      ...     ...       ...          ...
# 110                 eBooks   PERSON       1  0.004879     0.000000
# 111          mummy showman   PERSON       1  0.008826     0.000000
# 112  picturesque bungalows   PERSON       1  0.008826     0.000000
# 113                viharis   PERSON       1  0.008826     0.000000
# 114                  zebus   PERSON       1  0.002176     0.000000
#
# [115 rows x 5 columns]

# %% [markdown]
# ## Step - 6 Ploting a graph of collocated entities

# %%
def FgraphDraW_plotly(Fgraph, layout, vertexSize, vertexLabelSize, imageName, edgeLabelSize):   
    # vertex and edges atributes of Fgraph are treated as lists 
    G=Fgraph
    labels=G.vs['label']
    betweenness=G.vs['betweenness']
    degree = G.vs['degree']
    pagerank= G.vs['pagerank']
    ent_type= G.vs['ent_type']
    edgeSize = 2 # edge size for all
    N=len(labels) # number of nodes
    E=[e.tuple for e in G.es]# list of edges containing 
    layt=G.layout(layout) # layout https://igraph.org/python/doc/tutorial/tutorial.html#layouts-and-plotting
    ## node x, y components of the network
    Xn=[layt[k][0] for k in range(N)]
    Yn=[layt[k][1] for k in range(N)]
    ## edges from the layout
    Xe=[]
    Ye=[]
    for e in E:
        Xe+=[layt[e[0]][0],layt[e[1]][0], None]
        Ye+=[layt[e[0]][1],layt[e[1]][1], None]    
    
    fig=go.Figure(go.Scatter(x=Xe, y=Ye,
                mode='lines', name='Edges',
                line= dict(width=edgeSize, color='rgba(16, 112, 2, 0.5)', shape='spline', smoothing=1.3),
                hoverinfo='none'
                ))
    fig.add_trace(go.Scatter(x=Xn, y=Yn,
                mode='markers+text', 
                name='Lemma',
                marker=dict(symbol='circle-dot', 
                            size= [math.log(1/(1/(i+4)))*vertexSize for i in betweenness],
                            color='rgba(16, 112, 2, 0.5)',
                            line=dict(color='rgba(16, 112, 2, 0.5)', 
                            width=0.5)
                                ),
                text=labels, 
                textfont=dict(
                            family="IBM Plex Sans",
                            size=[math.log(1/(1/(i+5)))*vertexLabelSize*0.6 for i in degree],
                            color='rgba(0, 0, 0, 0.8)'#"crimson"
                        ),
                #https://chart-studio.plotly.com/~empet/15366/customdata-for-a-few-plotly-chart-types/#/
                customdata= np.stack((G.vs['betweenness'], G.vs['degree'], G.vs['pagerank'], G.vs['ent_type']), axis=-1),
                hovertemplate ="<b>%{text}</b><br>"+\
                                "Betweenness: %{customdata[0]}<br>"+\
                                "Degree: %{customdata[1]}<br>"+\
                                "PageRank: %{customdata[2]}<br>"+\
                                "Entity_type: %{customdata[3]}"
                                )
                    )
    fig.update_layout(go.Layout(title=imageName, 
                showlegend=False, autosize=True, hovermode='closest',
                font_size=10, font_family='IBM Plex Sans', 
                height=600,
                margin=dict(l=10, r=10, t=20, b=20),
                paper_bgcolor = 'rgba(0,0,0,0)', plot_bgcolor = 'rgba(255,255,250,0.5)',
                annotations=[dict(showarrow=False, xref='paper', yref='paper', 
                xanchor='center', yanchor='top', font=dict(size=14))], 
                xaxis=dict(showline=False, zeroline=False, showgrid=False, showticklabels=False),
                yaxis=dict(showline=False, zeroline=False, showgrid=False, showticklabels=False),
                ))   
    return (fig)

# %%
#FgraphDraW_plotly(Fgraph, layout, vertexSize, vertexLabelSize, imageName, edgeLabelSize)
FgraphDraW_plotly(g, 'fr', 8, 10, 'Network of characters', 3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6fbf187b-6adc-4292-bd99-2b55d5d181d8" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6fbf187b-6adc-4292-bd99-2b55d5d181d8")) {
#                     Plotly.newPlot(
#                         '6fbf187b-6adc-4292-bd99-2b55d5d181d8',
# ...

# %% [markdown]
# ### Further ideas
# * create a dynamic graph that tracks the cooccurences of Entities as a function of the sequential naration. Ex. (chapter 1 - graph, chapter -2 graph, etc; or more granularly with slider that maps the text location and span)

# %% [markdown]
# # Exploring syntactic relations for NE as a graph
# Going back to text we can now see the some syntactic dependencies. For instance, we could ask:
# * what are the typical characteristics/adjectives of subject|object related processes/verbs associated with an NE ?
# * how to entities overlap regarding these relations ?
# * ...

# %% [markdown]
# ## Two functions for creating and plotting graphs

# %%
def create_Igraph_from_source_friend_df(df):
  'takes source and friend column to create a simple graph'
  # https://stackoverflow.com/questions/44400345/create-igraph-graph-from-pandas-dataframe
  edges = df.astype('str').values.tolist()

  # collect the set of vertex names and then sort them into a list
  vertices = set()
  for line in edges:
      vertices.update(line)
  vertices = sorted(vertices)

  # create an empty graph
  g = igraph.Graph()

  # add vertices to the graph
  g.add_vertices(vertices)

  # add edges to the graph
  g.add_edges(edges)

  # set the weight of every edge to 1
  g.es["weight"] = 1

  # collapse multiple edges and sum their weights
  g.simplify(combine_edges={"weight": "sum"})

  g= g.simplify(combine_edges=max)
  g.vs["label"]= g.vs["name"]
  g.vs["degree"]=g.vs.degree()
  g.vs['betweenness'] = g.betweenness(vertices=None, directed=False, cutoff=None, weights=None, nobigint=True)
  g.vs["pagerank"]=g.vs.pagerank(directed=False, weights=None)
  return g

def F_depgraphDraW_plotly(Fgraph, layout, vertexSize, vertexLabelSize, imageName, edgeLabelSize):   
    # vertex and edges atributes of Fgraph are treated as lists 
    G=Fgraph
    labels=G.vs['label']
    betweenness=G.vs['betweenness']
    degree = G.vs['degree']
    pagerank= G.vs['pagerank']
    edgeSize = 2 # edge size for all
    N=len(labels) # number of nodes
    E=[e.tuple for e in G.es]# list of edges containing 
    layt=G.layout(layout) # layout https://igraph.org/python/doc/tutorial/tutorial.html#layouts-and-plotting
    ## node x, y components of the network
    Xn=[layt[k][0] for k in range(N)]
    Yn=[layt[k][1] for k in range(N)]
    ## edges from the layout
    Xe=[]
    Ye=[]
    for e in E:
        Xe+=[layt[e[0]][0],layt[e[1]][0], None]
        Ye+=[layt[e[0]][1],layt[e[1]][1], None]    
    
    fig=go.Figure(go.Scatter(x=Xe, y=Ye,
                mode='lines', name='Edges',
                line= dict(width=edgeSize, color='rgba(16, 112, 2, 0.5)', shape='spline', smoothing=1.3),
                hoverinfo='none'
                ))
    fig.add_trace(go.Scatter(x=Xn, y=Yn,
                mode='markers+text', 
                name='Lemma',
                marker=dict(symbol='circle-dot', 
                            size= [math.log(1/(1/(i+4)))*vertexSize for i in betweenness],
                            color='rgba(16, 112, 2, 0.5)',
                            line=dict(color='rgba(16, 112, 2, 0.5)', 
                            width=0.5)
                                ),
                text=labels, 
                textfont=dict(
                            family="IBM Plex Sans",
                            size=[math.log(1/(1/(i+5)))*vertexLabelSize*0.6 for i in degree],
                            color='rgba(0, 0, 0, 0.8)'#"crimson"
                        ),
                #https://chart-studio.plotly.com/~empet/15366/customdata-for-a-few-plotly-chart-types/#/
                customdata= np.stack((G.vs['betweenness'], G.vs['degree'], G.vs['pagerank']), axis=-1),
                hovertemplate ="<b>%{text}</b><br>"+\
                                "Betweenness: %{customdata[0]}<br>"+\
                                "Degree: %{customdata[1]}<br>"+\
                                "PageRank: %{customdata[2]}<br>"
                                )
                    )
    fig.update_layout(go.Layout(title=imageName+'with '+str(len(G.vs))+' nodes and '+str(len(G.es))+' edges', 
                showlegend=False, autosize=True, hovermode='closest',
                font_size=10, font_family='IBM Plex Sans', 
                height=600,
                margin=dict(l=10, r=10, t=20, b=20),
                paper_bgcolor = 'rgba(0,0,0,0)', plot_bgcolor = 'rgba(255,255,250,0.5)',
                annotations=[dict(showarrow=False, xref='paper', yref='paper', 
                xanchor='center', yanchor='top', font=dict(size=14))], 
                xaxis=dict(showline=False, zeroline=False, showgrid=False, showticklabels=False),
                yaxis=dict(showline=False, zeroline=False, showgrid=False, showticklabels=False),
                ))   
    return (fig)

# %% [markdown]
# ## Option 1 - Display the relations for a single NE

# %%
# select Named Entity
selected_NE='Fogg'
# represent dataset with mentioned entity 
df_selected_NE= df_doc[(df_doc['lemma']==selected_NE) ]
df_selected_NE.head()
# Out:
#      token lemma    POS conjuncts  ...   head head_i ent._iob_  ent._type_
# 824   Fogg  Fogg  PROPN        ()  ...  lived    825         I      PERSON
# 948   Fogg  Fogg  PROPN        ()  ...    was    949         I         ORG
# 1175  Fogg  Fogg  PROPN        ()  ...    was   1176         I         ORG
# 1243  Fogg  Fogg  PROPN        ()  ...   rich   1244         O
# 1269  Fogg  Fogg  PROPN        ()  ...    was   1270         B      PERSON
#
# [5 rows x 10 columns]

# %%
g_selected_NE= create_Igraph_from_source_friend_df(df_selected_NE[['lemma', 'head']])
#FgraphDraW_plotly(Fgraph, layout, vertexSize, vertexLabelSize, imageName, edgeLabelSize)
F_depgraphDraW_plotly(g_selected_NE, 'fr', 8, 10, 'Network of dependencies', 3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4a3a8d3b-c812-4152-83e9-3205eacabe6b" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a3a8d3b-c812-4152-83e9-3205eacabe6b")) {
#                     Plotly.newPlot(
#                         '4a3a8d3b-c812-4152-83e9-3205eacabe6b',
# ...

# %% [markdown]
# ### Display all dependencies related to a single entity

# %%
# all the possible dependencies related to the NE
selected_NE='London'
df_doc[(df_doc['lemma']==selected_NE) ]['dep'].unique()
# Out:
# array(['compound', 'nmod', 'pobj', 'dobj', 'appos', 'conj', 'nsubj'],
#       dtype=object)

# %% [markdown]
# ## Option -2 Explore one or more NE, with regards to one or more `dep`

# %%
# explore one or more NE,  dep
selected_NE=[ 'London', 'Calcutta', 'Singapore', 'Fogg']
selected_dep=['dobj',  'nsubj']
df_ent_dep= df_doc[(df_doc['lemma'].isin(selected_NE)) & (df_doc['dep'].isin(selected_dep)) ]
df_ent_dep
# Out:
#       token lemma    POS conjuncts  ...      head head_i ent._iob_  ent._type_
# 824    Fogg  Fogg  PROPN        ()  ...     lived    825         I      PERSON
# 948    Fogg  Fogg  PROPN        ()  ...       was    949         I         ORG
# 1175   Fogg  Fogg  PROPN        ()  ...       was   1176         I         ORG
# 1269   Fogg  Fogg  PROPN        ()  ...       was   1270         B      PERSON
# 1522   Fogg  Fogg  PROPN        ()  ...  absented   1525         I         ORG
# ...     ...   ...    ...       ...  ...       ...    ...       ...         ...
# 85256  Fogg  Fogg  PROPN        ()  ...   replied  85254         I         ORG
# 85330  Fogg  Fogg  PROPN        ()  ...    opened  85331         B      PERSON
# 85400  Fogg  Fogg  PROPN        ()  ...  returned  85398         B      PERSON
# 85438  Fogg  Fogg  PROPN        ()  ...      shut  85440         B      PERSON
# 85446  Fogg  Fogg  PROPN        ()  ...       won  85448         I         ORG
#
# [452 rows x 10 columns]

# %%
g_dep= create_Igraph_from_source_friend_df(df_ent_dep[['lemma', 'head']])
#FgraphDraW_plotly(Fgraph, layout, vertexSize, vertexLabelSize, imageName, edgeLabelSize)
F_depgraphDraW_plotly(g_dep, 'fr', 8, 10, 'Network of dependencies', 3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="94f1210e-69c4-42ad-a71f-e8b74c5971b5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("94f1210e-69c4-42ad-a71f-e8b74c5971b5")) {
#                     Plotly.newPlot(
#                         '94f1210e-69c4-42ad-a71f-e8b74c5971b5',
# ...

# %% [markdown]
# ## Option - 3 Explore all syntactical relations for number of Entities

# %%
# explore one or more NE
selected_NEs=[ 'London', 'Calcutta', 'Singapore', 'Fogg']
df_ents_dep= df_doc[(df_doc['lemma'].isin(selected_NEs))]
# create a graph
g_dep_all= create_Igraph_from_source_friend_df(df_ents_dep[['lemma', 'head']])
#FgraphDraW_plotly(Fgraph, layout, vertexSize, vertexLabelSize, imageName, edgeLabelSize)
F_depgraphDraW_plotly(g_dep_all, 'fr', 3, 10, 'Network of dependencies', 3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6b9e00e4-acc5-47dd-aa72-1745d96bec60" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6b9e00e4-acc5-47dd-aa72-1745d96bec60")) {
#                     Plotly.newPlot(
#                         '6b9e00e4-acc5-47dd-aa72-1745d96bec60',
# ...

# %% [markdown]
# ## Option 4 - Explore all  syntactical relations for all  Entities of a certain type

# %%
selected_NE_type=['PERSON']
all_NE_of_typeX= df_doc[(df_doc['ent._type_'].isin(selected_NE_type)) ]
g_dep_all= create_Igraph_from_source_friend_df(all_NE_of_typeX[['lemma', 'head']])
#FgraphDraW_plotly(Fgraph, layout, vertexSize, vertexLabelSize, imageName, edgeLabelSize)
F_depgraphDraW_plotly(g_dep_all, 'fr', 3, 10, 'Network of dependencies', 3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e544396e-a762-4ef8-8827-eb2ecd9ea9e8" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e544396e-a762-4ef8-8827-eb2ecd9ea9e8")) {
#                     Plotly.newPlot(
#                         'e544396e-a762-4ef8-8827-eb2ecd9ea9e8',
# ...

# %% [markdown]
# # GeoMapping data

# %% [markdown]
# ## Combining GoogleMaps with spacy
#
# This part uses the GoogleMaps tools explained in the :
# * https://colab.research.google.com/drive/1umGiTylqwvvVWnm_g9MrLSf1xJtemBDf?usp=sharing

# %%
# !pip install googlemaps
import googlemaps
#from datetime import datetime

# %%
key = 'AIzaSyCUOlud-dAnS3gXG5THkxB696T-EssVBac'

# %%
placeName= 'Calcutta'
gmaps = googlemaps.Client(key)
# Geocoding an address
geocode_result = gmaps.geocode(placeName)
geocode_result[0]
# Out:
# {'address_components': [{'long_name': 'Kolkata',
#    'short_name': 'Kolkata',
#    'types': ['locality', 'political']},
#   {'long_name': 'West Bengal',
#    'short_name': 'WB',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'India',
#    'short_name': 'IN',
#    'types': ['country', 'political']}],
#  'formatted_address': 'Kolkata, West Bengal, India',
#  'geometry': {'bounds': {'northeast': {'lat': 23.0083628, 'lng': 88.5428696},
#    'southwest': {'lat': 22.3436288, 'lng': 88.1165879}},
#   'location': {'lat': 22.572646, 'lng': 88.36389500000001},
#   'location_type': 'APPROXIMATE',
#   'viewport': {'northeast': {'lat': 23.0083628, 'lng': 88.5428696},
#    'southwest': {'lat': 22.3436288, 'lng': 88.1165879}}},
#  'place_id': 'ChIJZ_YISduC-DkRvCxsj-Yw40M',
#  'types': ['locality', 'political']}

# %%
geoPosition= geocode_result[0]['geometry']['location']
geoPosition
# Out:
# {'lat': 22.572646, 'lng': 88.36389500000001}

# %%
def get_location(placeName, key):
  'function that takes the placeName and returns {lat:value, lng:value}'
  try:
    gmaps = googlemaps.Client(key)
    # Geocoding an address
    geocode_result = gmaps.geocode(placeName)
    geocode_result[0]
    geoPosition= geocode_result[0]['geometry']['location']
    geoPosition
  except:
    pass
  return geoPosition

# %%
get_location('the Great Indian Peninsula Railway', key)
# Out:
# {'lat': 38.888684, 'lng': -77.004719}

# %% [markdown]
# ## Extract the geo entities and find their position

# %%
# select geoentities type
geo_entities_type= ['GPE', 'LOC']

geo_entities =[]
for ent in doc.ents:
  if ent.label_ in geo_entities_type: 
    entity = {'text':ent.text, 'label': ent.label_, 'start': ent.start}
    geo_entities.append(entity)

df_geo_entities= pd.DataFrame().from_dict(geo_entities)
df_geo_entities['text']=df_geo_entities['text'].str.replace('\r\n', ' ')
unique_geo_enities = df_geo_entities['text'].unique()
unique_geo_enities
# Out:
# array(['SERVANT', 'HONG KONG', 'XXVII', 'Byronic', 'the "City', 'London',
#        'Temple', 'Saville Row', 'Paris', 'France', 'England',
#        'the United Kingdom', 'a.m.', 'Pall Mall', 'America', 'Liverpool',
#        'Suez', 'New York', 'the Great Indian Peninsula Railway', 'Mont',
#        'Bombay', 'Hong Kong', 'Yokohama (Japan', 'Yokohama',
#        'San Francisco', 'Hindoos', 'Dover', 'Calais', 'Sydenham',
#        'the West End', 'Alabama', 'Europe', 'India', 'the United States',
#        'fogs', 'Fix', 'Detective', 'Mongolia', 'the Suez Canal',
#        'Brindisi', 'the Mongolia', 'Burglars', 'the Red Sea', 'Aden',
#        'Asia', 'Atlantic', 'Brindisi, Suez', 'Calcutta', 'Singapore',
#        'Egypt', 'Africa', 'the Arabic Gulf', 'the Indian Ocean', 'Madras',
#        'Bengal', 'Salcette', 'Tannah', 'the Western Ghauts', 'Bundelcund',
#        'Allahabad', 'Elephanta', 'the Island of Salcette', 'Kandallah',
# ...

# %%
# restriction sometimes necessary !!!!!
# restriction on the Google API key - ony 10 entities will be checked when you activate the script 
geo_positions= [] 
for item in unique_geo_enities[0:10]:
  # time.sleep(3)
  try: 
    geo_tuple= (item, get_location(item, key))
    geo_positions.append(geo_tuple)
  except:
    pass

# %%
geo_positions_df=pd.DataFrame().from_dict(geo_positions)
geo_positions_df[['lat', 'lng']]=geo_positions_df[1].apply(pd.Series)
geo_positions_df= geo_positions_df.drop(1, axis=1)
geo_positions_df
# Out:
#              0        lat         lng
# 0      SERVANT  42.292436  -83.857821
# 1    HONG KONG  22.319304  114.169361
# 2        XXVII  31.636602 -106.393864
# 3      Byronic  33.925094 -117.936062
# 4    the "City  40.783060  -73.971249
# ..         ...        ...         ...
# 222  GUTENBERG  41.885283  -87.621512
# 223  Gutenberg  41.885283  -87.621512
# 224     DIRECT  36.333856  -94.156245
# 225   INDIRECT  41.816488  -87.723095
# 226       U.S.  37.090240  -95.712891
#
# [227 rows x 3 columns]

# %%
geo_positions_df['lat'].mean()
# Out:
# 35.496254860792966

# %%
geo_positions_df['lat'][0]
# Out:
# 42.2924363

# %%
geo_positions_df[0][0]
# Out:
# 'SERVANT'

# %%
! pip install folium

# %%
import folium

# %%
m = folium.Map(location=[geo_positions_df['lat'].mean(),geo_positions_df['lng'].mean()], zoom_start=5, tiles='Stamen Terrain')
for index, geoEntity in geo_positions_df.iterrows():
  tooltip=geoEntity[0]
  folium.Marker(
      [geoEntity['lat'],geoEntity['lng']], popup=f"<i>{geoEntity[0]}</i>", tooltip=tooltip
  ).add_to(m)  
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
