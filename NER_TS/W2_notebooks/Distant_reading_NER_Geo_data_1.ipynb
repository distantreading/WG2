# %% [markdown]
# *Distant reading NER Training School*
#
# *24.3.2021.*
# ## Data Analysis, Representation of the Geo-Entities and Enrichment of the Data Using Wikipedia
#
# ### Benedikt Perak
# Cultural Complexity Lab - University of Rijeka
#
# bperak@uniri.hr

# %% [markdown]
# # Resources
#
# ## Main tools
# * https://colab.research.google.com/
# * https://wikipedia.readthedocs.io/
# * https://python-visualization.github.io/folium/
# * https://www.mediawiki.org/wiki/API:Geosearch
#
# ## Distant reading
# * https://github.com/distantreading
# ### NER Workshop
# * https://github.com/distantreading/WG2/tree/master/NER_TS
# * https://github.com/distantreading/WG2/tree/master/NER_TS/TXT_samples
# https://github.com/distantreading/WG2/tree/master/NER_TS/novels
#
#
# ### Additional resources
# * https://en.wikipedia.org/wiki/Wikipedia:Obtaining_geographic_coordinates
# * https://github.com/codingforentrepreneurs/30-Days-of-Python/tree/master/tutorial-reference/Day%2020

# %% [markdown]
# # Aim
# Demonstrate the workflow for data gathering and representing data using:
# * Google Colab as a colaborative platform for online python programming
# * Wikipedia python package
# * Mediawiki.org/wiki/API:Geosearch
# * Folium geo representation python package

# %% [markdown]
# <h1>From data to knowledge</h1>
#
# <p><img alt="Colaboratory logo" height="250px" src="https://www.researchgate.net/profile/BL_Wong/publication/272242493/figure/fig2/AS:339539152392194@1457963850280/Two-Perspectives-on-Data-Information-Knowledge-Wisdom-DIKW-In-practice-of-course.png" align="center" hspace="10px" vspace="0px"></p>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
# <h1> Google colab</h1>
# <h2>What is Colaboratory?</h2>
#
# Colaboratory, or "Colab" for short, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Free access to GPUs
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %%
# This is an comment within a code cell 
# please execute the cell by clicking the go icon to the left of the cell
print("Hello good people")
# Out:
# Hello good people

# %% [markdown]
# ### Practice task
# * print some random statement in the code cell below

# %%
# print some random statement here in the line below 
# (when you are done, be sure to activate it using the play button or using CTRL+Enter )

# %% [markdown]
# <p><img alt="Wikipedia logo" height="50px" src="https://upload.wikimedia.org/wikipedia/en/thumb/8/80/Wikipedia-logo-v2.svg/1024px-Wikipedia-logo-v2.svg.png" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>Wikipedia python package</h1>
#
# Wikipedia package is a Python library that makes it easy to access and parse data from Wikipedia.
#
# Search Wikipedia, get article summaries, get data, links and images from a page, and more. Wikipedia wraps the MediaWiki API so you can focus on using Wikipedia data, not getting it.
#
# Documentation how to start using the Wikipedia package can be found here:
# * https://wikipedia.readthedocs.io/en/latest/code.html

# %%
# install wikipedia (we install library packages in the colab using the !pip install <name of the package> )
# !pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.7/dist-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wikipedia) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.24.3)

# %%
# import wikipedia in memory
import wikipedia

# %% [markdown]
# ## Setting a language for a Wikipedia
# The data is searched using a language-specific version of Wikipedia.
#
# You can list all the currently supported language prefixes (usually ISO language code)by running:
# ```
# wikipedia.languages()
# ```

# %%
wikipedia.languages()
# Out:
# {'aa': 'Qafár af',
#  'ab': 'Аҧсшәа',
#  'abs': 'bahasa ambon',
#  'ace': 'Acèh',
#  'ady': 'адыгабзэ',
#  'ady-cyrl': 'адыгабзэ',
#  'aeb': 'تونسي/Tûnsî',
#  'aeb-arab': 'تونسي',
#  'aeb-latn': 'Tûnsî',
#  'af': 'Afrikaans',
#  'ak': 'Akan',
#  'aln': 'Gegë',
#  'als': 'Alemannisch',
#  'alt': 'алтай тил',
#  'am': 'አማርኛ',
#  'ami': 'Pangcah',
#  'an': 'aragonés',
#  'ang': 'Ænglisc',
#  'anp': 'अङ्गिका',
#  'ar': 'العربية',
#  'arc': 'ܐܪܡܝܐ',
#  'arn': 'mapudungun',
#  'arq': 'جازايرية',
#  'ary': 'الدارجة',
#  'arz': 'مصرى',
#  'as': 'অসমীয়া',
#  'ase': 'American sign language',
#  'ast': 'asturianu',
#  'atj': 'Atikamekw',
#  'av': 'авар',
#  'avk': 'Kotava',
#  'awa': 'अवधी',
#  'ay': 'Aymar aru',
#  'az': 'azərbaycanca',
#  'azb': 'تۆرکجه',
#  'ba': 'башҡортса',
#  'ban': 'Basa Bali',
#  'ban-bali': 'ᬩᬲᬩᬮᬶ',
#  'bar': 'Boarisch',
#  'bat-smg': 'žemaitėška',
#  'bbc': 'Batak Toba',
#  'bbc-latn': 'Batak Toba',
#  'bcc': 'جهلسری بلوچی',
#  'bcl': 'Bikol Central',
#  'be': 'беларуская',
#  'be-tarask': 'беларуская (тарашкевіца)\u200e',
#  'be-x-old': 'беларуская (тарашкевіца)\u200e',
#  'bg': 'български',
#  'bgn': 'روچ کپتین بلوچی',
#  'bh': 'भोजपुरी',
#  'bho': 'भोजपुरी',
#  'bi': 'Bislama',
#  'bjn': 'Banjar',
#  'bm': 'bamanankan',
#  'bn': 'বাংলা',
#  'bo': 'བོད་ཡིག',
#  'bpy': 'বিষ্ণুপ্রিয়া মণিপুরী',
#  'bqi': 'بختیاری',
#  'br': 'brezhoneg',
#  'brh': 'Bráhuí',
#  'bs': 'bosanski',
#  'btm': 'Batak Mandailing',
#  'bto': 'Iriga Bicolano',
#  'bug': 'ᨅᨔ ᨕᨘᨁᨗ',
#  'bxr': 'буряад',
#  'ca': 'català',
#  'cbk-zam': 'Chavacano de Zamboanga',
#  'cdo': 'Mìng-dĕ̤ng-ngṳ̄',
#  'ce': 'нохчийн',
#  'ceb': 'Cebuano',
#  'ch': 'Chamoru',
#  'cho': 'Choctaw',
#  'chr': 'ᏣᎳᎩ',
#  'chy': 'Tsetsêhestâhese',
#  'ckb': 'کوردی',
#  'co': 'corsu',
#  'cps': 'Capiceño',
#  'cr': 'Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ',
#  'crh': 'qırımtatarca',
#  'crh-cyrl': 'къырымтатарджа (Кирилл)\u200e',
#  'crh-latn': 'qırımtatarca (Latin)\u200e',
#  'cs': 'čeština',
#  'csb': 'kaszëbsczi',
#  'cu': 'словѣньскъ / ⰔⰎⰑⰂⰡⰐⰠⰔⰍⰟ',
#  'cv': 'Чӑвашла',
#  'cy': 'Cymraeg',
#  'da': 'dansk',
#  'de': 'Deutsch',
#  'de-at': 'Österreichisches Deutsch',
#  'de-ch': 'Schweizer Hochdeutsch',
#  'de-formal': 'Deutsch (Sie-Form)\u200e',
#  'din': 'Thuɔŋjäŋ',
#  'diq': 'Zazaki',
#  'dsb': 'dolnoserbski',
#  'dtp': 'Dusun Bundu-liwan',
#  'dty': 'डोटेली',
#  'dv': 'ދިވެހިބަސް',
#  'dz': 'ཇོང་ཁ',
#  'ee': 'eʋegbe',
#  'egl': 'Emiliàn',
#  'el': 'Ελληνικά',
#  'eml': 'emiliàn e rumagnòl',
#  'en': 'English',
#  'en-ca': 'Canadian English',
#  'en-gb': 'British English',
#  'eo': 'Esperanto',
#  'es': 'español',
#  'es-419': 'español de América Latina',
#  'es-formal': 'español (formal)\u200e',
#  'et': 'eesti',
#  'eu': 'euskara',
#  'ext': 'estremeñu',
#  'fa': 'فارسی',
#  'ff': 'Fulfulde',
#  'fi': 'suomi',
#  'fit': 'meänkieli',
#  'fiu-vro': 'võro',
#  'fj': 'Na Vosa Vakaviti',
#  'fo': 'føroyskt',
#  'fr': 'français',
#  'frc': 'français cadien',
#  'frp': 'arpetan',
#  'frr': 'Nordfriisk',
#  'fur': 'furlan',
#  'fy': 'Frysk',
#  'ga': 'Gaeilge',
#  'gag': 'Gagauz',
#  'gan': '贛語',
#  'gan-hans': '赣语（简体）\u200e',
#  'gan-hant': '贛語（繁體）\u200e',
#  'gcr': 'kriyòl gwiyannen',
#  'gd': 'Gàidhlig',
#  'gl': 'galego',
#  'glk': 'گیلکی',
#  'gn': "Avañe'ẽ",
#  'gom': 'गोंयची कोंकणी / Gõychi Konknni',
#  'gom-deva': 'गोंयची कोंकणी',
#  'gom-latn': 'Gõychi Konknni',
#  'gor': 'Bahasa Hulontalo',
#  'got': '𐌲𐌿𐍄𐌹𐍃𐌺',
#  'grc': 'Ἀρχαία ἑλληνικὴ',
#  'gsw': 'Alemannisch',
#  'gu': 'ગુજરાતી',
#  'guc': 'wayuunaiki',
#  'gv': 'Gaelg',
#  'ha': 'Hausa',
#  'hak': '客家語/Hak-kâ-ngî',
#  'haw': 'Hawaiʻi',
#  'he': 'עברית',
#  'hi': 'हिन्दी',
#  'hif': 'Fiji Hindi',
#  'hif-latn': 'Fiji Hindi',
#  'hil': 'Ilonggo',
#  'ho': 'Hiri Motu',
#  'hr': 'hrvatski',
#  'hrx': 'Hunsrik',
#  'hsb': 'hornjoserbsce',
#  'ht': 'Kreyòl ayisyen',
#  'hu': 'magyar',
#  'hu-formal': 'magyar (formal)\u200e',
#  'hy': 'հայերեն',
#  'hyw': 'Արեւմտահայերէն',
#  'hz': 'Otsiherero',
#  'ia': 'interlingua',
#  'id': 'Bahasa Indonesia',
#  'ie': 'Interlingue',
#  'ig': 'Igbo',
#  'ii': 'ꆇꉙ',
#  'ik': 'Iñupiak',
#  'ike-cans': 'ᐃᓄᒃᑎᑐᑦ',
#  'ike-latn': 'inuktitut',
#  'ilo': 'Ilokano',
#  'inh': 'ГӀалгӀай',
#  'io': 'Ido',
#  'is': 'íslenska',
#  'it': 'italiano',
#  'iu': 'ᐃᓄᒃᑎᑐᑦ/inuktitut',
#  'ja': '日本語',
#  'jam': 'Patois',
#  'jbo': 'la .lojban.',
#  'jut': 'jysk',
#  'jv': 'Jawa',
#  'ka': 'ქართული',
#  'kaa': 'Qaraqalpaqsha',
#  'kab': 'Taqbaylit',
#  'kbd': 'Адыгэбзэ',
#  'kbd-cyrl': 'Адыгэбзэ',
#  'kbp': 'Kabɩyɛ',
#  'kcg': 'Tyap',
#  'kg': 'Kongo',
#  'khw': 'کھوار',
#  'ki': 'Gĩkũyũ',
#  'kiu': 'Kırmancki',
#  'kj': 'Kwanyama',
#  'kjp': 'ဖၠုံလိက်',
#  'kk': 'қазақша',
#  'kk-arab': 'قازاقشا (تٴوتە)\u200f',
#  'kk-cn': 'قازاقشا (جۇنگو)\u200f',
#  'kk-cyrl': 'қазақша (кирил)\u200e',
#  'kk-kz': 'қазақша (Қазақстан)\u200e',
#  'kk-latn': 'qazaqşa (latın)\u200e',
#  'kk-tr': 'qazaqşa (Türkïya)\u200e',
#  'kl': 'kalaallisut',
#  'km': 'ភាសាខ្មែរ',
#  'kn': 'ಕನ್ನಡ',
#  'ko': '한국어',
#  'ko-kp': '조선말',
#  'koi': 'перем коми',
#  'kr': 'Kanuri',
#  'krc': 'къарачай-малкъар',
#  'kri': 'Krio',
#  'krj': 'Kinaray-a',
#  'krl': 'karjal',
#  'ks': 'कॉशुर / کٲشُر',
#  'ks-arab': 'کٲشُر',
#  'ks-deva': 'कॉशुर',
#  'ksh': 'Ripoarisch',
#  'ku': 'kurdî',
#  'ku-arab': 'كوردي (عەرەبی)\u200f',
#  'ku-latn': 'kurdî (latînî)\u200e',
#  'kum': 'къумукъ',
#  'kv': 'коми',
#  'kw': 'kernowek',
#  'ky': 'Кыргызча',
#  'la': 'Latina',
#  'lad': 'Ladino',
#  'lb': 'Lëtzebuergesch',
#  'lbe': 'лакку',
#  'lez': 'лезги',
#  'lfn': 'Lingua Franca Nova',
#  'lg': 'Luganda',
#  'li': 'Limburgs',
#  'lij': 'Ligure',
#  'liv': 'Līvõ kēļ',
#  'lki': 'لەکی',
#  'lld': 'Ladin',
#  'lmo': 'lumbaart',
#  'ln': 'lingála',
#  'lo': 'ລາວ',
#  'loz': 'Silozi',
#  'lrc': 'لۊری شومالی',
#  'lt': 'lietuvių',
#  'ltg': 'latgaļu',
#  'lus': 'Mizo ţawng',
#  'luz': 'لئری دوٙمینی',
#  'lv': 'latviešu',
#  'lzh': '文言',
#  'lzz': 'Lazuri',
#  'mad': 'Madhurâ',
#  'mai': 'मैथिली',
#  'map-bms': 'Basa Banyumasan',
#  'mdf': 'мокшень',
#  'mg': 'Malagasy',
#  'mh': 'Ebon',
#  'mhr': 'олык марий',
#  'mi': 'Māori',
#  'min': 'Minangkabau',
#  'mk': 'македонски',
#  'ml': 'മലയാളം',
#  'mn': 'монгол',
#  'mni': 'ꯃꯤꯇꯩ ꯂꯣꯟ',
#  'mnw': 'ဘာသာ မန်',
#  'mo': 'молдовеняскэ',
#  'mr': 'मराठी',
#  'mrh': 'Mara',
#  'mrj': 'кырык мары',
#  'ms': 'Bahasa Melayu',
#  'mt': 'Malti',
#  'mus': 'Mvskoke',
#  'mwl': 'Mirandés',
#  'my': 'မြန်မာဘာသာ',
#  'myv': 'эрзянь',
#  'mzn': 'مازِرونی',
#  'na': 'Dorerin Naoero',
#  'nah': 'Nāhuatl',
#  'nan': 'Bân-lâm-gú',
#  'nap': 'Napulitano',
#  'nb': 'norsk bokmål',
#  'nds': 'Plattdüütsch',
#  'nds-nl': 'Nedersaksies',
#  'ne': 'नेपाली',
#  'new': 'नेपाल भाषा',
#  'ng': 'Oshiwambo',
#  'nia': 'Li Niha',
#  'niu': 'Niuē',
#  'nl': 'Nederlands',
#  'nl-informal': 'Nederlands (informeel)\u200e',
#  'nn': 'norsk nynorsk',
#  'no': 'norsk',
#  'nov': 'Novial',
#  'nqo': 'ߒߞߏ',
#  'nrm': 'Nouormand',
#  'nso': 'Sesotho sa Leboa',
#  'nv': 'Diné bizaad',
#  'ny': 'Chi-Chewa',
#  'nys': 'Nyunga',
#  'oc': 'occitan',
#  'olo': 'livvinkarjala',
#  'om': 'Oromoo',
#  'or': 'ଓଡ଼ିଆ',
#  'os': 'Ирон',
#  'pa': 'ਪੰਜਾਬੀ',
#  'pag': 'Pangasinan',
#  'pam': 'Kapampangan',
#  'pap': 'Papiamentu',
#  'pcd': 'Picard',
#  'pdc': 'Deitsch',
#  'pdt': 'Plautdietsch',
#  'pfl': 'Pälzisch',
#  'pi': 'पालि',
#  'pih': 'Norfuk / Pitkern',
#  'pl': 'polski',
#  'pms': 'Piemontèis',
#  'pnb': 'پنجابی',
#  'pnt': 'Ποντιακά',
#  'prg': 'Prūsiskan',
#  'ps': 'پښتو',
#  'pt': 'português',
#  'pt-br': 'português do Brasil',
#  'qu': 'Runa Simi',
#  'qug': 'Runa shimi',
#  'rgn': 'Rumagnôl',
#  'rif': 'Tarifit',
#  'rm': 'rumantsch',
#  'rmy': 'romani čhib',
#  'rn': 'Kirundi',
#  'ro': 'română',
#  'roa-rup': 'armãneashti',
#  'roa-tara': 'tarandíne',
#  'ru': 'русский',
#  'rue': 'русиньскый',
#  'rup': 'armãneashti',
#  'ruq': 'Vlăheşte',
#  'ruq-cyrl': 'Влахесте',
#  'ruq-latn': 'Vlăheşte',
#  'rw': 'Kinyarwanda',
#  'sa': 'संस्कृतम्',
#  'sah': 'саха тыла',
#  'sat': 'ᱥᱟᱱᱛᱟᱲᱤ',
#  'sc': 'sardu',
#  'scn': 'sicilianu',
#  'sco': 'Scots',
#  'sd': 'سنڌي',
#  'sdc': 'Sassaresu',
#  'sdh': 'کوردی خوارگ',
#  'se': 'davvisámegiella',
#  'sei': 'Cmique Itom',
#  'ses': 'Koyraboro Senni',
#  'sg': 'Sängö',
#  'sgs': 'žemaitėška',
#  'sh': 'srpskohrvatski / српскохрватски',
#  'shi': 'Taclḥit',
#  'shi-latn': 'Taclḥit',
#  'shi-tfng': 'ⵜⴰⵛⵍⵃⵉⵜ',
#  'shn': 'ၽႃႇသႃႇတႆး ',
#  'shy': 'tacawit',
#  'shy-latn': 'tacawit',
#  'si': 'සිංහල',
#  'simple': 'Simple English',
#  'sk': 'slovenčina',
#  'skr': 'سرائیکی',
#  'skr-arab': 'سرائیکی',
#  'sl': 'slovenščina',
#  'sli': 'Schläsch',
#  'sm': 'Gagana Samoa',
#  'sma': 'åarjelsaemien',
#  'smn': 'anarâškielâ',
#  'sn': 'chiShona',
#  'so': 'Soomaaliga',
#  'sq': 'shqip',
#  'sr': 'српски / srpski',
#  'sr-ec': 'српски (ћирилица)\u200e',
#  'sr-el': 'srpski (latinica)\u200e',
#  'srn': 'Sranantongo',
#  'ss': 'SiSwati',
#  'st': 'Sesotho',
#  'stq': 'Seeltersk',
#  'sty': 'себертатар',
#  'su': 'Sunda',
#  'sv': 'svenska',
#  'sw': 'Kiswahili',
#  'szl': 'ślůnski',
#  'szy': 'Sakizaya',
#  'ta': 'தமிழ்',
#  'tay': 'Tayal',
#  'tcy': 'ತುಳು',
#  'te': 'తెలుగు',
#  'tet': 'tetun',
#  'tg': 'тоҷикӣ',
#  'tg-cyrl': 'тоҷикӣ',
#  'tg-latn': 'tojikī',
#  'th': 'ไทย',
#  'ti': 'ትግርኛ',
#  'tk': 'Türkmençe',
#  'tl': 'Tagalog',
#  'tly': 'tolışi',
#  'tly-cyrl': 'толыши',
#  'tn': 'Setswana',
#  'to': 'lea faka-Tonga',
#  'tpi': 'Tok Pisin',
#  'tr': 'Türkçe',
#  'tru': 'Ṫuroyo',
#  'trv': 'Seediq',
#  'ts': 'Xitsonga',
#  'tt': 'татарча/tatarça',
#  'tt-cyrl': 'татарча',
#  'tt-latn': 'tatarça',
#  'tum': 'chiTumbuka',
#  'tw': 'Twi',
#  'ty': 'reo tahiti',
#  'tyv': 'тыва дыл',
#  'tzm': 'ⵜⴰⵎⴰⵣⵉⵖⵜ',
#  'udm': 'удмурт',
#  'ug': 'ئۇيغۇرچە / Uyghurche',
#  'ug-arab': 'ئۇيغۇرچە',
#  'ug-latn': 'Uyghurche',
#  'uk': 'українська',
#  'ur': 'اردو',
#  'uz': 'oʻzbekcha/ўзбекча',
#  'uz-cyrl': 'ўзбекча',
#  'uz-latn': 'oʻzbekcha',
#  've': 'Tshivenda',
#  'vec': 'vèneto',
#  'vep': 'vepsän kel’',
#  'vi': 'Tiếng Việt',
#  'vls': 'West-Vlams',
#  'vmf': 'Mainfränkisch',
#  'vo': 'Volapük',
#  'vot': 'Vaďďa',
#  'vro': 'võro',
#  'wa': 'walon',
#  'war': 'Winaray',
#  'wo': 'Wolof',
#  'wuu': '吴语',
#  'xal': 'хальмг',
#  'xh': 'isiXhosa',
#  'xmf': 'მარგალური',
#  'xsy': 'saisiyat',
#  'yi': 'ייִדיש',
#  'yo': 'Yorùbá',
#  'yue': '粵語',
#  'za': 'Vahcuengh',
#  'zea': 'Zeêuws',
#  'zgh': 'ⵜⴰⵎⴰⵣⵉⵖⵜ ⵜⴰⵏⴰⵡⴰⵢⵜ',
#  'zh': '中文',
#  'zh-classical': '文言',
#  'zh-cn': '中文（中国大陆）\u200e',
#  'zh-hans': '中文（简体）\u200e',
#  'zh-hant': '中文（繁體）\u200e',
#  'zh-hk': '中文（香港）\u200e',
#  'zh-min-nan': 'Bân-lâm-gú',
#  'zh-mo': '中文（澳門）\u200e',
#  'zh-my': '中文（马来西亚）\u200e',
#  'zh-sg': '中文（新加坡）\u200e',
#  'zh-tw': '中文（台灣）\u200e',
#  'zh-yue': '粵語',
#  'zu': 'isiZulu'}

# %% [markdown]
# To change the language of the API being requested just set prefix to one of the two letter prefixes found on the list of all Wikipedias. For example:
#
# `wikipedia.set_lang("en")`
#
# will change the search for English version of Wikipedia, etc.

# %%
# set language to italian
wikipedia.set_lang("it")

# %% [markdown]
# ## Searching a summary for a concept
# Plain text summary of the page.The summary of a concept can be obtained by
#
# ```
# wikipedia.summary(query, sentences=0, chars=0, auto_suggest=True, redirect=True)
# ```
#
# This is a convenience wrapper - auto_suggest and redirect are enabled by default

# %%
# search for a concept and get the summary from Wikipedia
wikipedia.summary('Fiume, Hrvatska')
# Out:
# "Fiume (AFI: /ˈfjume/; in croato Rijeka, /rijěːka/; in ungherese Fiume, originariamente Szentvit; in sloveno Reka; in tedesco Sankt Veit am Flaum o Pflaum, desueto; nei dialetti locali croati Reka o Rika), con 128 624 abitanti (2011), è la terza città della Croazia per popolazione dopo la capitale Zagabria e Spalato, numero che sale a 305 505 abitanti se si considera anche la sua area urbana. Situata lungo le coste del Mare Adriatico, è la città principale del golfo del Quarnaro (o Quarnero) ed è capoluogo della regione litoraneo-montana, sede universitaria e arcivescovile. Fiume fa parte della regione geografica italiana, per i cui confini orientali tradizionalmente si indicano la catena delle Alpi Giulie e il golfo del Quarnaro, a cui fa riferimento anche Dante Alighieri.\nPer secoli contesa a causa della sua posizione strategica e della presenza di un importante cantiere navale, fu porto franco dal 1719, già entità autonoma (detta anche Terra Sancti Viti ad flumen) della corona del Regno d'Ungheria dal 1779 al 1919 nell'ambito dell'Impero austriaco e quindi di quello austro-ungarico, costituendo poi lo Stato libero di Fiume dal 1920 al 1924; fu quindi parte del Regno d'Italia dal 1924 al 1945 come capoluogo dell'omonima provincia per poi passare alla Jugoslavia nel 1947, e dopo la dissoluzione di quest'ultima, alla Croazia nel 1991. Di conseguenza, anche la composizione etnica dei suoi abitanti è cambiata nei secoli. Secondo il censimento del 2011, a Fiume erano presenti 106 136 croati (corrispondenti all'82,52% degli abitanti totali), 8 446 serbi (6,57%), 2 650 bosniaci (2,06%), 2 445 italiani (1,90%) e 1 090 sloveni (0,85%).\nNella città quarnerina è presente il Teatro Nazionale Croato HNK Ivan pl.Zajc, importante teatro fondato nel 1765 dove hanno luogo rappresentazioni operistiche e balletti nonché sede del Dramma Italiano di Fiume, e l'università di Fiume, fondata nel 1973 ma dalle radici ben più antiche, visto che affondano nella scuola di teologia di Fiume, la cui origine risale al 1632. Fiume è stata scelta per essere capitale europea della cultura 2020, insieme all'irlandese Galway."

# %% [markdown]
# ### Practice task
# * set language to English
# * search for a concept and print the summary from Wikipedia

# %%
# set language to English

# search for the geo concept and print the summary from Wikipedia

# %% [markdown]
# ## Get the data about the page from Wikipedia package

# %%
# search for the place and store it in the variable placeName
wikipedia.set_lang("it")
placeName= "Firenza"
print(wikipedia.summary(placeName))
# Out:
# Firenze (AFI: /fiˈrεnʦe/; ; in epoca medievale e nel linguaggio poetico anche Fiorenza, /fjoˈrɛnʦa/) è una città italiana di 361 057 abitanti, capoluogo della Toscana e centro della città metropolitana; è il primo comune della regione per popolazione, cuore dell'area metropolitana di Firenze-Prato-Pistoia.
# Nel Medioevo è stata un importante centro artistico, culturale, commerciale, politico, economico e finanziario; nell'età moderna ha ricoperto il ruolo di capitale del Granducato di Toscana dal 1569 al 1859 che, con il governo delle famiglie dei Medici e dei Lorena, divenne uno degli stati più ricchi e moderni. Le varie vicissitudini politiche, la potenza finanziaria e mercantile e le influenze in ogni campo della cultura hanno fatto della città un crocevia fondamentale della storia italiana ed europea. Nel 1865 Firenze fu proclamata capitale del Regno d'Italia (seconda, dopo Torino), mantenendo questo status fino al 1871, anno che segna la fine del Risorgimento.
# Importante centro universitario e patrimonio dell'umanità UNESCO dal 1982, è considerata luogo d'origine del Rinascimento – la consapevolezza di una nuova era moderna dopo il Medioevo, periodo di cambiamento e "rinascita" culturale e scientifica – e della lingua italiana grazie al volgare fiorentino usato nella letteratura. È universalmente riconosciuta come una delle culle dell'arte e dell'architettura, nonché rinomata tra le più belle città del mondo, grazie ai suoi numerosi monumenti e musei tra cui il Duomo, Santa Croce, Santa Maria Novella, gli Uffizi, Ponte Vecchio, Piazza della Signoria, Palazzo Vecchio e Palazzo Pitti. Di inestimabile valore i lasciti artistici, letterari e scientifici di geni del passato come Petrarca, Boccaccio, Brunelleschi, Michelangelo, Giotto, Cimabue, Botticelli, Leonardo da Vinci, Donatello, Lorenzo de’ Medici, Machiavelli, Galileo Galilei e Dante Alighieri, che fanno del centro storico di Firenze uno dei luoghi con la più alta concentrazione di opere d'arte al mondo. La ricchezza del patrimonio storico-artistico, scientifico, naturalistico e paesaggistico rendono il centro e le colline circostanti un vero e proprio "museo diffuso".

# %%
# What is a page of the place in Wikipedia
page= wikipedia.page(title=placeName, pageid=True, auto_suggest=True, redirect=True, preload=False)
page
# Out:
# <WikipediaPage 'Firenze'>

# %% [markdown]
# Once you have the page of a geolocation you can search for various metadata stored on the wikipedia page: Categories, content, coordinates, html, links, images, references, sections, summary.

# %%
# List of categories of a page.
page.categories
# Out:
# ['Categoria:Firenze',
#  'Categoria:Organizzare',
#  'Categoria:P2044 letta da Wikidata',
#  'Categoria:P2046 uguale su Wikidata',
#  'Categoria:P281 letta da Wikidata',
#  'Categoria:P395 letta da Wikidata',
#  'Categoria:P41 letta da Wikidata',
#  'Categoria:P473 letta da Wikidata',
#  'Categoria:P625 letta da Wikidata',
#  'Categoria:P635 letta da Wikidata',
#  'Categoria:P806 letta da Wikidata',
#  'Categoria:P856 differente su Wikidata',
#  'Categoria:P94 letta da Wikidata',
#  'Categoria:Pagine che utilizzano Timeline',
#  'Categoria:Pagine con collegamenti non funzionanti',
#  'Categoria:Template Webarchive - collegamenti a WebCite',
#  "Categoria:Template Webarchive - collegamenti all'Internet Archive",
#  'Categoria:Voci con codice BNF',
#  'Categoria:Voci con codice GND',
#  'Categoria:Voci con codice LCCN',
#  'Categoria:Voci con codice NDL',
#  'Categoria:Voci con codice VIAF',
#  'Categoria:Voci con codice WorldCat Identities',
#  'Categoria:Voci con modulo citazione e parametro pagina',
#  'Categoria:Voci non biografiche con codici di controllo di autorità']

# %%
# Plain text summary of the page.
page.summary
# Out:
# 'Firenze (AFI: /fiˈrεnʦe/; ; in epoca medievale e nel linguaggio poetico anche Fiorenza, /fjoˈrɛnʦa/) è una città italiana di 361 057 abitanti, capoluogo della Toscana e centro della città metropolitana; è il primo comune della regione per popolazione, cuore dell\'area metropolitana di Firenze-Prato-Pistoia.\nNel Medioevo è stata un importante centro artistico, culturale, commerciale, politico, economico e finanziario; nell\'età moderna ha ricoperto il ruolo di capitale del Granducato di Toscana dal 1569 al 1859 che, con il governo delle famiglie dei Medici e dei Lorena, divenne uno degli stati più ricchi e moderni. Le varie vicissitudini politiche, la potenza finanziaria e mercantile e le influenze in ogni campo della cultura hanno fatto della città un crocevia fondamentale della storia italiana ed europea. Nel 1865 Firenze fu proclamata capitale del Regno d\'Italia (seconda, dopo Torino), mantenendo questo status fino al 1871, anno che segna la fine del Risorgimento.\nImportante centro universitario e patrimonio dell\'umanità UNESCO dal 1982, è considerata luogo d\'origine del Rinascimento – la consapevolezza di una nuova era moderna dopo il Medioevo, periodo di cambiamento e "rinascita" culturale e scientifica – e della lingua italiana grazie al volgare fiorentino usato nella letteratura. È universalmente riconosciuta come una delle culle dell\'arte e dell\'architettura, nonché rinomata tra le più belle città del mondo, grazie ai suoi numerosi monumenti e musei tra cui il Duomo, Santa Croce, Santa Maria Novella, gli Uffizi, Ponte Vecchio, Piazza della Signoria, Palazzo Vecchio e Palazzo Pitti. Di inestimabile valore i lasciti artistici, letterari e scientifici di geni del passato come Petrarca, Boccaccio, Brunelleschi, Michelangelo, Giotto, Cimabue, Botticelli, Leonardo da Vinci, Donatello, Lorenzo de’ Medici, Machiavelli, Galileo Galilei e Dante Alighieri, che fanno del centro storico di Firenze uno dei luoghi con la più alta concentrazione di opere d\'arte al mondo. La ricchezza del patrimonio storico-artistico, scientifico, naturalistico e paesaggistico rendono il centro e le colline circostanti un vero e proprio "museo diffuso".'

# %%
# List of URLs of images on the page.
page.images
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/a/a0/2946_-_Firenze_-_Porta_San_Niccol%C3%B2_-_Foto_Giovanni_Dall%27Orto_-_28-Oct-2007.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/2a/Aeronautica_Militare_Frecce_tricolori_Firenze_2018_MG_1588_03.gif',
#  'https://upload.wikimedia.org/wikipedia/commons/c/ce/Aeroporto_di_firenze_check_in.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c5/Arco_di_Trionfo_%28Florence%29_122.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/0/04/BNCF_7.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a7/Basilica_di_san_lorenzo_33.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/e/e4/Battistero%2C_Campanile_di_Giotto_e_Duomo_di_Firenze.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/60/Battistero%2C_Duomo_e_Campanile_di_Giotto.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/fa/Battistero_di_San_Giovanni_%28Firenze%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c3/Biblioteca_Nazionale_Firenze_2008.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/79/Boboli_Gardens.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/e/e8/Calcio_Storico_Corteo.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/aa/Careggi_Hospital_entry.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/73/Casino_corsini_al_prato_02.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/a/af/Ciborio_barocco_dell%27altare_maggiore_della_Basilica_di_Santo_Spirito_%28Firenze%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/65/Cimitero_USA_Firenze.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/f/f1/Cityscape_of_Florence_in_the_Night.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4f/Coat_of_arms_of_Tuscany.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4a/Commons-logo.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/6e/Complesso_delle_murate_04.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/9/9b/Crystal128-file-broken.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d3/Dante_Alighieri01.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d5/David_von_Michelangelo.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/23/Duomo_Firenze_2019.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/60/FiIMG_0189_bordercropped.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/ff/Firenze-piazza_signoria_statue04.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/1b/FirenzePalazzoPittiPiazzale.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/5/51/Firenze_-_Badia%2C_bargello_e_Santa_Croce_da_Campanile_di_giotto.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/e/e7/Firenze_-_Chiesa_di_San_Lorenzo_da_cupola_duomo.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d1/Firenze_-_Galleria_degli_Uffizi%2C_corridoio_livello_superiore.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/3/3a/Firenze_-_Piazzale_Michelangelo%2C_Firenze%2C_Italy_-_April_6%2C_2015_02.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/0/03/Firenze_Bargello_2.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/22/Firenze_FI.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/1/19/Firenze_da_Ponte_Vecchio.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/5/56/Firenze_view.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/3/36/Flag_of_Albania.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Australia.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/41/Flag_of_Austria.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/0/05/Flag_of_Brazil.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/8f/Flag_of_Estonia.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_Finland.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a4/Flag_of_Florence.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c3/Flag_of_France.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/b/ba/Flag_of_Germany.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c1/Flag_of_Hungary.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/ca/Flag_of_Iran.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d4/Flag_of_Israel.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/0/03/Flag_of_Italy.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/9e/Flag_of_Japan.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/aa/Flag_of_Kuwait.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Latvia.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/fc/Flag_of_Mexico.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/2c/Flag_of_Morocco.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/0/00/Flag_of_Palestine.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/cf/Flag_of_Peru.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/12/Flag_of_Poland.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/9a/Flag_of_Spain.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4c/Flag_of_Sweden.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/49/Flag_of_Ukraine.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/26/Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/fa/Flag_of_the_People%27s_Republic_of_China.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/26/Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/ae/Flag_of_the_United_Kingdom.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a4/Flag_of_the_United_States.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/e/e0/Fleur_de_lis_of_Florence.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c1/Florence%27s_districts.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/ae/FlorenceCoA.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/9e/Florence_Cathedral_Fa%C3%A7ade.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/3/33/Florence_Ponte_Vecchio_bridge_at_night.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/6f/Florence_vue_depuis_Fiesole.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/a/aa/Florencja_Il_Porcelino_RB.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c9/Fontana_del_Nettuno_%28Florence%29_2_2013_February.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/71/Francesco_Petrarca2.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/23/Galleno%2C_via_Francigena_lastricata_e_Osteria_di_Greppi_%28Fab18_2015%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/15/Giardino_bardini%2C_panorama_04.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/3/32/Giardino_dell%27Orticultura_7.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/b/be/Gilli_%28Florence%29_Piazza_della_Repubblica.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/60/Giovanni_Boccaccio_statua.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/7c/It-Firenze.ogg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/16/Italy_provincial_location_map_2016.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/7b/Le_mura_di_Firenze.jpeg',
#  'https://upload.wikimedia.org/wikipedia/commons/b/b4/Logo_unifi.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/87/Magnifying_glass_icon_mgx2.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/e/e7/Map_of_comune_of_Florence_%28province_of_Florence%2C_region_Tuscany%2C_Italy%29.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/fb/Mercato_ortofrutticolo_di_novoli.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/0/0c/Museo_del_bargello%2C_cortile.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/88/Palazzo_Pitti_2019.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/f7/Palazzo_Strozzi%2C_Firenze.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/3/35/Palazzo_Vecchio_%282019%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/77/Palazzo_Vecchio_Apr_2008.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c3/Palazzo_medici_riccardi_33.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a7/Parco_demidoff2012-10-21_16.20.13.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c5/Piano_Poggi_%28Firenze%2C_1865%29_-_1.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/3/37/Piazza_SS_Annunziata_Firenze_Apr_2008.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/12/Piazza_del_Duomo_FI.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/22/Piazza_del_Duomo_FI_.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/0/0d/Piazza_di_Santa_Trinita_%283845540897%29_%282%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/92/Ponte_Vecchio_2019.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/89/Ponte_Vecchio_Firenze_4.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d5/Porta_romana%2C_di_mattina%2C_01.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/f/f7/Provincia_di_Firenze-Stemma.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/b/b7/Quartieri_storici_Firenze.png',
#  'https://upload.wikimedia.org/wikipedia/commons/0/0c/Red_pog.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/2f/Rivoire_%28Florence%29_1.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/6/62/SanMiniatoAlMonte-Cimetiere.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d0/SanMiniatoalMontenew.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/46/Santa_Croce_2019.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/e/ea/Santa_Maria_Novella_2019.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/cb/Santa_Maria_Novella_Square3124.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c4/Stazione_Santa_Maria_Novella_2.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/8/85/Stazione_lazzi_piazza_adua.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/1/1f/Teatro_della_Pergola.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/c/ca/Torre_dei_mannelli_33.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/b/b6/Torre_della_castagna_23.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/e/e3/Uffizi_Gallery%2C_Florence.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/15/Valor_civile_gold_medal_BAR.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/7c/Valor_militare_gold_medal_BAR.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/1f/Vechio_Ponte_Santa_Trinita_with_the_Oltrarno_district.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/b/be/Via_Tornabuoni_2019.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/0/03/Via_de_Tornabuoni_03.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d9/Via_dei_Calzaiuoli_03.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/6/66/Via_de%E2%80%99_Tornabuoni%2C_Piazza_Antinori_e_Chiesa_dei_Santi_Michele_e_Gaetano.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/42/Via_de%E2%80%99_Tornabuoni.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/12/Viale_Spartaco_Lavagnini_%28Firenze%29_6.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/2/23/Villa_del_poggio_imperiale%2C_esterno_06.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/5/5d/Villa_medicea_di_Castello_Facciata_%28vista_frontale%29.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/2/24/Wikinews-logo.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/fa/Wikiquote-logo.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/d/dd/Wikivoyage-Logo-v3-icon.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/f9/Wiktionary_small.svg',
#  'https://upload.wikimedia.org/wikipedia/it/c/c3/Mandela_forum.jpg']

# %%
from IPython.display import Image
Image(page.images[3], width=400)

# %%
# List of titles of Wikipedia page links on a page.
# Only includes articles from namespace 0, meaning no Category, User talk, or other meta-Wikipedia pages.
page.links
# Out:
# ['055 (prefisso)',
#  '1066',
#  '1115',
#  '1251',
#  '1252',
#  '1269',
#  '1284',
#  '1293',
#  '1312',
#  '1314',
#  '1321',
#  '1345',
#  '1348',
#  '1378',
#  '1382',
#  '1403',
#  '1406',
#  '1434',
#  '1437',
#  '1498',
#  '1512',
#  '1527',
#  '1530',
#  '1532',
#  '1555',
#  '1569',
#  '1648',
#  '1654',
#  '1670',
#  '1737',
#  '1786',
#  '1809',
#  '1817',
#  '1822',
#  '1827',
#  '1829',
#  '1844',
#  '1849',
#  '1859',
#  '1861',
#  '1865',
#  '1871',
#  '1894',
#  '1895',
#  '1926',
#  '1931',
#  '1937',
#  '1940',
#  '1944',
#  '1963',
#  '1964',
#  '1966',
#  '1973',
#  '1982',
#  '1983',
#  '1985',
#  '1992',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '27 agosto',
#  '59 a.C.',
#  '7 Gold',
#  'ACF Fiorentina',
#  'ATAF',
#  'Aarhus',
#  'Abbazia',
#  'Abruzzo',
#  'Accademia Italiana',
#  'Accademia dei Georgofili',
#  'Accademia del Cimento',
#  'Accademia della Crusca',
#  'Accademia delle arti del disegno',
#  'Accademia di belle arti di Firenze',
#  'Accademia neoplatonica',
#  'Acqua Panna',
#  'Acquedotto Carolino',
#  'Adami (azienda)',
#  'Adriano',
#  'Aeroporto di Firenze-Campo di Marte',
#  'Aeroporto di Firenze-Peretola',
#  'Aeroporto di Pisa-San Giusto',
#  'Agenzia Italiana per la Sicurezza delle ferrovie',
#  "Agenzia Regionale per lo Sviluppo e l'Innovazione nel Settore Agricolo e Forestale",
#  "Agenzia nazionale per le nuove tecnologie, l'energia e lo sviluppo economico sostenibile",
#  'Agnolo Bronzino',
#  'Agosto',
#  'Agrigento',
#  'Al-Kuwait',
#  'Albania',
#  'Alberobello',
#  'Albizi',
#  'Aleandro Baldi',
#  'Alessandria',
#  'Alessandro Canino',
#  'Alessandro Contini Bonacossi',
#  'Alessandro Paci',
#  'Alfabeto fonetico internazionale',
#  'Alluvione di Firenze',
#  'Alta moda',
#  'Alta velocità ferroviaria',
#  'Altitudine',
#  'Alto medioevo',
#  'Amerigo Vespucci',
#  'Amministrazione digitale',
#  'Amsterdam',
#  'Ancillotti',
#  'Ancona',
#  'Andrea Pisano',
#  'Andrea del Verrocchio',
#  'Andria',
#  'Anello del Rinascimento',
#  'Angeli del fango',
#  'Angelo Maria Bandini',
#  'Angelo Poliziano',
#  'Anni 1930',
#  'Anni settanta',
#  'Anno',
#  'Antica Grecia',
#  'Antonino Pierozzi',
#  'Antonio Canova',
#  'Antonio Paolucci',
#  'Antonio Pollaiolo',
#  'Anversa',
#  'Aosta',
#  'Appartamenti monumentali',
#  'Appennino tosco-emiliano',
#  'Aprile',
#  'Aquileia',
#  'Arcetri',
#  'Architettura',
#  'Architettura romanica in Italia',
#  'Archivio di Stato di Firenze',
#  'Arcidiocesi di Firenze',
#  'Arcispedale di Santa Maria Nuova',
#  'Arco di San Pierino',
#  'Arco di Trionfo (Firenze)',
#  'Arco di trionfo (Firenze)',
#  'Area',
#  'Area metropolitana di Firenze',
#  'Area metropolitana di Firenze, Prato e Pistoia',
#  'Arequipa',
#  'Arezzo',
#  'Arno',
#  'Arnold Böcklin',
#  'Arnolfo di Cambio',
#  'Arte',
#  'Arte romanica',
#  'Artemio Franchi',
#  'Arthur Hugh Clough',
#  'Arti di Firenze',
#  'Artigianato',
#  'Asburgo',
#  'Ascoli Piceno',
#  "Assassin's Creed Brotherhood",
#  "Assassin's Creed II",
#  'Associazione Sportiva Dilettantistica Ponte Rondinella Marzocco',
#  'Asti',
#  'Atene',
#  'Atlanta',
#  'Aulla',
#  'Austria',
#  'Auto condivisa',
#  'Autobus',
#  'Automobili Florentia',
#  'Autostrada A11 (Italia)',
#  'Autostrada A1 (Italia)',
#  'Autostrada del Sole',
#  'Autunno',
#  'Avellino',
#  'Avignone',
#  'Azienda Ospedaliero-Universitaria Careggi',
#  'Azienda ospedaliero-universitaria Careggi',
#  'BNCF',
#  'Baccio Bandinelli',
#  'Bad Ischl',
#  'Badia Fiorentina',
#  'Badia fiorentina',
#  'Bagno a Ripoli',
#  'Bagno di Romagna',
#  'Banca CR Firenze',
#  'Banca Popolare Etica',
#  'Banca Toscana',
#  'Bandabardò',
#  'Bangladesh',
#  'Barberino Tavarnelle',
#  'Barberino di Mugello',
#  'Bari',
#  'Barletta',
#  'Barocco',
#  'Bartolomeo Ammannati',
#  'Bartolomeo Cristofori',
#  'Basilica della Santissima Annunziata',
#  'Basilica di San Francesco',
#  'Basilica di San Lorenzo (Firenze)',
#  'Basilica di San Miniato al Monte',
#  'Basilica di San Paolo fuori le mura',
#  'Basilica di San Pietro in Vaticano',
#  'Basilica di Santa Croce',
#  'Basilica di Santa Maria Novella',
#  'Basilica di Santo Spirito',
#  'Basilicata',
#  'Battaglia di Colle',
#  'Battaglia di Scannagallo',
#  'Battistero di San Giovanni (Firenze)',
#  'Beato Angelico',
#  'Beatrice Portinari',
#  'Belgio',
#  'Bellosguardo (Firenze)',
#  'Belluno',
#  'Belvedere di San Leucio',
#  'Benevento',
#  'Benozzo Gozzoli',
#  'Benvenuto Cellini',
#  'Bergamo',
#  'Bergen',
#  'Berlino Ovest',
#  'Bernard Berenson',
#  'Bernardo Buontalenti',
#  'Beta Motor',
#  'Betlemme',
#  'Bianchi e Neri',
#  'Bibbiena',
#  'Biblioteca Comunale Centrale',
#  'Biblioteca Marucelliana',
#  'Biblioteca Medicea Laurenziana',
#  'Biblioteca Mediceo Laurenziana',
#  'Biblioteca Moreniana',
#  'Biblioteca Nazionale Centrale di Firenze',
#  'Biblioteca Pietro Thouar',
#  'Biblioteca Riccardiana',
#  'Biblioteca degli Uffizi',
#  "Biblioteca dell'Accademia della Crusca",
#  'Biblioteca della Dieta nazionale del Giappone',
#  'Biblioteca delle Carra',
#  'Biblioteca delle Oblate',
#  'Biblioteca di Palagio di Parte Guelfa',
#  'Biblioteca e archivio del Risorgimento',
#  'Biblioteche di Firenze',
#  'Bibliothèque nationale de France',
#  'Biella',
#  'Bigiotteria',
#  'Bistecca alla fiorentina',
#  'Boccaccio',
#  'Bodø',
#  'Bologna',
#  'Bolsena',
#  'Bolzano',
#  'Borgo Ognissanti',
#  'Borgo San Lorenzo',
#  'Borgo dei Greci',
#  'Bottega Teatrale di Firenze',
#  'Botticelli',
#  'Boulevard',
#  'Braccialini',
#  'Brasile',
#  'Brescia',
#  'Breslavia',
#  'Bressanone',
#  'Brigate partigiane',
#  'Brindisi',
#  'British Institute of Florence',
#  'Bruges',
#  'Brunelleschi',
#  'Bruno Migliorini',
#  'Bruno Walter',
#  'Bruxelles (comune)',
#  'Budapest',
#  'Bugnato',
#  'Bulgaria',
#  'Buontalenti',
#  'Busitalia-Sita Nord',
#  'Béla Bartók',
#  'Caffè Gilli',
#  'Caffè Le Giubbe Rosse',
#  'Cagliari',
#  'Calabria',
#  'Calcio (sport)',
#  'Calcio in costume',
#  'Calcio storico fiorentino',
#  'Calenzano',
#  'California State University',
#  'Caltanissetta',
#  'Camerata fiorentina',
#  'Campania',
#  'Campanile di Giotto',
#  'Campi Bisenzio',
#  'Campionati del mondo di ciclismo su strada',
#  'Campionati del mondo di ciclismo su strada 2013',
#  'Campo di Marte (Firenze)',
#  'Campobasso',
#  'Canale 10 Firenze',
#  'Canale Macinante',
#  'Cannes',
#  'Canoa/kayak',
#  'Canottaggio',
#  'Canto a tenore',
#  'Canzoniere (Petrarca)',
#  'Capitale (città)',
#  'Capitale europea della cultura',
#  'Capo Verde',
#  'Capoluogo',
#  'Cappella Brancacci',
#  'Cappella Sassetti',
#  'Cappella dei Magi',
#  'Cappella dei Pazzi',
#  'Cappella della Madonna della Neve (Firenze)',
#  'Cappella di Eleonora',
#  'Cappelle Medicee',
#  'Cappelle medicee',
#  'Cappello di paglia di Firenze',
#  'Capraia e Limite',
#  'Caravaggio',
#  'Carbonia',
#  'Careggi',
#  'Carlo Buti',
#  'Carlo Collodi',
#  'Carlo Goldoni',
#  'Carmelo Bene',
#  'Carne',
#  'Casa-studio di Galileo Chini',
#  'Casa Buonarroti',
#  'Casa Editrice Barbèra',
#  'Casa Francioni Pampaloni',
#  'Casa Vasari (Firenze)',
#  'Casa di Andrea del Sarto',
#  'Casa di Benvenuto Cellini',
#  'Casa di Bernardo Buontalenti',
#  'Casa di Giovan Battista Foggini',
#  'Casa di Giuseppe Martelli',
#  'Casa di Ignazio Villa',
#  'Casa di Jacopo Pontormo',
#  'Casa di Lorenzo Bartolini',
#  'Casa di Lorenzo Ghiberti',
#  'Casa natale di Desiderio da Settignano',
#  'Caserta',
#  'Castagnaccio',
#  'Castel del Monte',
#  'Castelfiorentino',
#  'Castiglion Fiorentino',
#  'Castiglione dei Pepoli',
#  'Castiglione del Lago',
#  'Castrocaro',
#  'Castrum',
#  'Catania',
#  'Catanzaro',
#  'Cattedrale di Saint Paul',
#  'Cattedrale di Santa Maria del Fiore',
#  'Cattedrale di Siviglia',
#  'Cenacolo',
#  'Cenacolo di Santo Spirito',
#  'Cenotafi',
#  'Centro di documentazione Matteo Lanzoni di Polimoda',
#  'Centro e museo didattico nazionale',
#  'Centro storico di Firenze',
#  'Centro storico di Genova',
#  'Centro storico di Napoli',
#  'Centro storico di Roma',
#  'Centro tecnico federale della Federazione Italiana Giuoco Calcio',
#  'Centro traumatologico ortopedico (Firenze)',
#  'Cercina',
#  'Cerreto Guidi',
#  'Certaldo',
#  'Certosa di Firenze',
#  'Certosa di Padula',
#  'Cervello alla fiorentina',
#  'Chemnitz',
#  'Chiacchiere',
#  'Chianti (vino)',
#  'Chiesa (architettura)',
#  'Chiesa Russa Ortodossa della Natività',
#  'Chiesa del Carmine (Firenze)',
#  'Chiesa di Ognissanti (Firenze)',
#  'Chiesa di San Frediano in Cestello',
#  'Chiesa di San Lorenzo (Firenze)',
#  'Chiesa di San Pier Maggiore (Firenze)',
#  'Chiesa di Santa Felicita (Firenze)',
#  'Chiesa di Santa Maria Maggiore (Firenze)',
#  'Chiesa di Santa Maria Novella',
#  'Chiesa di Santa Maria degli Angeli (Firenze)',
#  'Chiesa di Santa Maria delle Grazie (Milano)',
#  'Chiesa di Santa Trinita (Firenze)',
#  'Chiesa di Santo Spirito (Firenze)',
#  'Chiese di Firenze',
#  'Chieti',
#  'Chilometro',
#  'Chilometro quadrato',
#  'Christoph Willibald Gluck',
#  'Cimabue',
#  'Cimiteri di Firenze',
#  'Cimitero Israelitico (Firenze)',
#  'Cimitero Monumentale Ebraico di Firenze',
#  'Cimitero degli Allori',
#  'Cimitero degli inglesi (Firenze)',
#  'Cimitero dei Pinti',
#  'Cimitero delle Ballodole',
#  'Cimitero delle Porte Sante',
#  'Cimitero di Soffiano',
#  'Cimitero di Trespiano',
#  'Cimitero monumentale ebraico di Firenze',
#  'Cina',
#  'Cinque Terre',
#  'Ciro Menotti',
#  'Cistercensi',
#  "Città d'arte",
#  'Città decorate al Valor Militare per la Guerra di Liberazione',
#  'Città della Pieve',
#  'Città metropolitana',
#  'Città metropolitana di Bologna',
#  'Città metropolitana di Firenze',
#  "Città metropolitane d'Italia",
#  'Città tardo barocche del Val di Noto',
#  'City (quotidiano)',
#  'Civiltà villanoviana',
#  'Classificazione climatica',
#  'Classificazione climatica dei comuni italiani',
#  'Classificazione dei climi di Köppen',
#  'Classificazione sismica',
#  "Classificazione sismica dell'Italia",
#  'Clima della Toscana',
#  'Clima di Firenze',
#  'Clima subtropicale',
#  'Clima temperato',
#  'Clima temperato umido',
#  'Clinica chirurgica di Careggi',
#  'Codice catastale',
#  'Codice postale',
#  'Colle del Moncenisio',
#  'Colline del Chianti',
#  'Colline del Prosecco di Conegliano e Valdobbiadene',
#  'Colombia',
#  'Colonna della Giustizia',
#  "Commedia dell'arte",
#  'Como',
#  'Complesso di San Filippo Neri',
#  'Complesso di San Firenze',
#  'Complesso monumentale delle Murate',
#  'Comune (Italia)',
#  'Comune medievale',
#  "Comuni d'Italia",
#  'Comuni della Toscana',
#  'Comuni italiani per popolazione',
#  'Comunità Europea',
#  'Conservatorio Luigi Cherubini',
#  'Consiglio Nazionale delle Ricerche',
#  'Consiglio Regionale della Toscana',
#  'Consoli e podestà di Firenze',
#  'Consorzio Autolinee Pratesi',
#  'Conte of Florence',
#  'Conte of Florence International Approach Championship',
#  'Contempo Records',
#  'Conti Guidi',
#  'Controradio (Firenze)',
#  'Convento delle Oblate Ospitaliere Francescane di Monna Tessa',
#  'Convento di San Marco',
#  'Convenzione di settembre',
#  'Coordinate geografiche',
#  'Copenaghen',
#  'Copit',
#  'Coppa Italia',
#  'Coppa delle Coppe (calcio)',
#  'Cork',
#  'Corridoio vasariano',
#  'Corriere Fiorentino',
#  'Cortona',
#  'Cosenza',
#  'Cosimo I',
#  "Cosimo I de' Medici",
#  "Cosimo de' Medici",
#  'Cosimo il Vecchio',
#  'Costa Rica',
#  "Costa d'Avorio",
#  'Costiera amalfitana',
#  'Coverciano',
#  'Cracovia',
#  'Cremona',
#  "Crespi d'Adda",
#  'Crocifisso di Santa Croce',
#  'Crocifisso di Santo Spirito',
#  "Cronica delle cose occorrenti ne' tempi suoi",
#  'Crotone',
#  'Cucina fiorentina',
#  'Cultura',
#  'Cultura underground',
#  'Cuneo',
#  'Cupola del Brunelleschi',
#  'Cutigliano',
#  "D'Annunzio",
#  'Danimarca',
#  'Dante',
#  'Dante Alighieri',
#  'Dario Nardella',
#  'David (Donatello, bronzo)',
#  'David Zabriskie',
#  'David di Michelangelo',
#  'Decameron',
#  'Delizie estensi',
#  'Delta del Po',
#  'Democrazia Cristiana',
#  'Densità di popolazione',
#  'Diaframma (gruppo musicale)',
#  'Dialetto toscano',
#  'Dicembre',
#  'Dicomano',
#  'Dieta mediterranea',
#  'Diffusività atmosferica',
#  'Dimitri Mitropoulos',
#  'Dino Compagni',
#  'Diocleziano',
#  'Dirotta su Cuba',
#  'Divina Commedia',
#  "Dizionario d'ortografia e di pronunzia",
#  'Dizionario di pronuncia italiana',
#  'Dolomiti',
#  'Domenicana',
#  'Domenico Ghirlandaio',
#  'Domine',
#  'Domodossola',
#  'Donatello',
#  'Donati',
#  'Dresda',
#  'Dublino',
#  'Duca',
#  'Duca di Lorena',
#  'Ducato di Massa e Carrara',
#  'Ducato di Modena',
#  'Duomo di Firenze',
#  'Duomo di Milano',
#  'Duomo di Modena',
#  'Dürer',
#  'Ebanisteria',
#  'Ecuador',
#  'Edilizia popolare',
#  'Edimburgo',
#  'Edizioni Remo Sandron',
#  'Egitto',
#  'El Aaiún',
#  'El Salvador',
#  'Elea-Velia',
#  'Elena Sofia Ricci',
#  'Eleonora di Toledo',
#  'Eleusi',
#  'Eli Lilly and Company',
#  'Elia Volpi',
#  'Elisa Baciocchi',
#  'Elizabeth Barrett Browning',
#  'Emilia-Romagna',
#  'Emilio De Fabris',
#  'Emilio Pucci (azienda)',
#  'Empoli',
#  'Enna',
#  'Enrico Coveri',
#  'Enrico Fermi',
#  'Enrico Novelli',
#  'Ercole e Caco',
#  'Ermanno Scervino',
#  'Erminio Macario',
#  'Esch-sur-Alzette',
#  'Esfahan',
#  'Essen',
#  'Estate',
#  'Estonia',
#  'Etna',
#  'Etnico (onomastica)',
#  'Etruria',
#  'Etruschi',
#  'Ettore Scola',
#  'Europa',
#  'European University Institute',
#  'Eventi a Firenze',
#  'Faenza',
#  'Faggeta vetusta depressa di Monte Raschio',
#  "Fagioli all'uccelletto",
#  'Febbraio',
#  'Federico Zuccari',
#  'Felice Le Monnier',
#  "Ferdinando II de' Medici",
#  'Fermo',
#  'Ferrara',
#  'Ferrovia Bologna-Firenze (alta velocità)',
#  'Ferrovia Faentina',
#  'Ferrovia Firenze-Bologna (direttissima)',
#  'Ferrovia Firenze-Roma',
#  'Ferrovia Firenze-Roma (direttissima)',
#  'Ferrovia Leopolda',
#  'Ferrovia Maria Antonia',
#  'Ferrovia Porrettana',
#  'Ferrovia Retica',
#  'Ferrovia del Bernina',
#  'Fes',
#  'Fidenza',
#  'Fiesole',
#  'Figline Valdarno',
#  'Figline e Incisa Valdarno',
#  'Filadelfia',
#  'Filippine',
#  'Filippino Lippi',
#  'Filippo Brunelleschi',
#  'Filippo Lippi',
#  'Filippo Marinetti',
#  'Findomestic',
#  'Finlandia',
#  'Fiorentina Baseball',
#  'Fiorentina Waterpolo',
#  "Fiorenzuola d'Arda",
#  'Fiorino',
#  'Firenze Capitale',
#  'Firenze Fiera',
#  'Firenzuola',
#  'Fiume (Croazia)',
#  'Fiume Arno',
#  'Florence American Cemetery and Memorial',
#  'Florence Declaration',
#  'Florence War Cemetery',
#  'Florentia',
#  'Florida State University',
#  'Foggia',
#  'Fondazione Spadolini Nuova Antologia',
#  'Fondiaria Sai',
#  'Fontana del Nettuno (Firenze)',
#  "Foreste primordiali dei faggi dei Carpazi e di altre regioni d'Europa",
#  'Forlì',
#  'Fornovo di Taro',
#  'Forte Belvedere',
#  'Forte di Belvedere',
#  'Fortezza da Basso',
#  'Fortificazione alla moderna',
#  'Francesco Guicciardini',
#  'Francesco Hayez',
#  'Francesco Petrarca',
#  'Francesco Stefano di Lorena',
#  'Francesi',
#  'Franchi',
#  'Francia',
#  'Franco Zeffirelli',
#  'Fratelli Alinari',
#  'Fratelli Rosselli',
#  'Frazione (geografia)',
#  'Frederick Stibbert',
#  'Frittelle di riso di san Giuseppe',
#  'Friuli-Venezia Giulia',
#  'Frosinone',
#  'Fucecchio',
#  'Furti napoleonici',
#  'Fuso orario',
#  'Gabinetto Vieusseux',
#  'Gaio Mario',
#  'Galileo Galilei',
#  'Gallarate',
#  'Galleria Palatina',
#  'Galleria Pio Fedi',
#  'Galleria Rinaldo Carnielo',
#  "Galleria d'arte moderna",
#  "Galleria d'arte moderna (Firenze)",
#  'Galleria degli Uffizi',
#  'Galleria del Costume',
#  'Galleria del costume',
#  "Galleria dell'Accademia",
#  'Galluzzo',
#  'Galway',
#  'Gambassi Terme',
#  'Gemeinsame Normdatei',
#  'Gennaio',
#  'Genova',
#  'Genova capitale europea della cultura',
#  "Georgia (Stati Uniti d'America)",
#  'Gerhard Wolf',
#  'Germania',
#  'Gherardini',
#  'Ghiaccio',
#  'Ghibellini',
#  'Ghirlandina',
#  'Giacomo Balla',
#  'Giambologna',
#  'Gian Domenico Ferretti',
#  'Giano della Bella',
#  'Giapponesi',
#  'Giardini della Fortezza',
#  'Giardini di Firenze',
#  'Giardino Bardini',
#  'Giardino Torrigiani',
#  'Giardino dei Giusti (Firenze)',
#  'Giardino dei Semplici',
#  "Giardino dell'Iris",
#  "Giardino dell'Orticultura",
#  'Giardino della Gherardesca',
#  'Giardino delle Rose',
#  'Giardino delle Rose (Firenze)',
#  'Giardino di Boboli',
#  'Gifu',
#  'Giglio bottonato',
#  'Giglio di Firenze',
#  'Ginevra Di Marco',
#  'Gioachino Rossini',
#  'Gioconda',
#  'Gioielleria',
#  'Giorgio Albertazzi',
#  'Giorgio De Chirico',
#  'Giorgio Panariello',
#  'Giorgio Vasari',
#  'Giorno',
#  'Giorno di gelo',
#  'Giorno di pioggia',
#  'Giorno festivo',
#  'Giotto',
#  'Giovan Pietro Vieusseux',
#  'Giovanni Boccaccio',
#  'Giovanni Boldini',
#  'Giovanni Duprè',
#  'Giovanni Fattori',
#  'Giovanni Gentile',
#  'Giovanni Michelucci',
#  'Giovanni Spadolini',
#  'Giovanni Villani',
#  "Giro d'Italia",
#  "Giro d'Italia 1989",
#  "Giro d'Italia 2005",
#  "Giro d'Italia 2009",
#  "Giro d'Italia 2013",
#  'Girolamo Savonarola',
#  'Giugno',
#  'Giuliano da Sangallo',
#  'Giunti Editore',
#  'Giuseppe Bezzuoli',
#  'Giuseppe Poggi',
#  'Giuseppe Verdi',
#  'Glasgow',
#  'Gorizia',
#  'Gotico',
#  'Gotico italiano',
#  'Grado Celsius',
#  'Grado giorno',
#  'Gran Bretagna',
#  'Gran Caffè Doney',
#  'Granduca di Toscana',
#  'Granducato di Toscana',
#  'Gravellona Toce',
#  'Graz',
#  'Grecia',
#  'Greve (fiume)',
#  'Greve in Chianti',
#  'Grosseto',
#  'Gruppo Dada',
#  'Gucci',
#  'Guelfi',
#  'Guelfi Firenze',
#  'Guelfi neri e bianchi',
#  'Guglielmo Marconi',
#  'Guimarães',
#  'Gustaf Gründgens',
#  'Hard Rock Cafe',
#  'Harold Acton',
#  'Helsinki',
#  'Herbert Percy Horne',
#  'Herbert von Karajan',
#  'I.R.A. Records',
#  'INDIRE',
#  'ISBN',
#  'IV secolo',
#  'IX secolo a.C.',
#  "Igor' Fëdorovič Stravinskij",
#  'Il Firenze',
#  'Il Nuovo Corriere di Firenze',
#  'Il Ponte (rivista)',
#  'Il burbero benefico',
#  'Imperatore del Sacro Romano Impero',
#  'Imperia',
#  'Impero bizantino',
#  'Impero spagnolo',
#  'Impruneta',
#  'Incisioni rupestri della Val Camonica',
#  'India',
#  'Indro Montanelli',
#  'Inglesi',
#  'Ingmar Bergman',
#  'Innsbruck',
#  'Internet Archive',
#  'Inverno',
#  'Ippodromo delle Cascine',
#  'Irene Grandi',
#  'Iris florentina',
#  'Isernia',
#  'Isola del Tino',
#  'Isole Eolie',
#  'Istanbul',
#  'Istituto Geografico Militare',
#  'Istituto Ortopedico Toscano',
#  "Istituto Statale d'Arte di Firenze",
#  "Istituto agronomico per l'oltremare",
#  'Istituto dei sistemi complessi',
#  'Istituto italiano di scienze umane',
#  "Istituto nazionale di documentazione per l'innovazione e la ricerca educativa",
#  'Istituto nazionale di statistica',
#  'Italia',
#  'Italia 7 Toscana',
#  'Italia centrale',
#  'Italia insulare',
#  'Italia meridionale',
#  'Italia nord-occidentale',
#  'Italia nord-orientale',
#  'Ivrea',
#  'Jean Dauberval',
#  'Joseph Haydn',
#  'Karlheinz Stockhausen',
#  'Kassel',
#  'Kaunas',
#  'Kiev',
#  'Košice',
#  'Krypton (compagnia teatrale)',
#  'Kyōto',
#  "L'Aquila",
#  "L'Unità",
#  'La Nazione',
#  'La Nuova Italia',
#  'La Repubblica (quotidiano)',
#  'La Spezia',
#  'La Valletta',
#  'La figlia malcustodita',
#  'Laboratorio europeo di spettroscopia non lineare',
#  'Lagonegro',
#  'Laguna di Venezia',
#  'Lampredotto',
#  'Langhe',
#  'Lapidi della Divina Commedia',
#  'Lastra a Signa',
#  'Latina',
#  'Lazio',
#  'Lazzi',
#  'Le Monnier',
#  'Le Strade Nuove e il Sistema dei Palazzi dei Rolli di Genova',
#  'Lecce',
#  'Lecco',
#  'Lech Piasecki',
#  'Leeuwarden',
#  'Lega Italiana Calcio Professionistico',
#  'Legambiente',
#  'Legge ordinaria',
#  'Leggo',
#  'Legnano',
#  'Leo S. Olschki',
#  'Leon Battista Alberti',
#  'Leonardo Pieraccioni',
#  'Leonardo Savioli',
#  'Leonardo da Vinci',
#  "Leopoldo II d'Asburgo-Lorena",
#  'Lettonia',
#  'Libero consorzio comunale',
#  'Library of Congress Control Number',
#  'Libreria Editrice Felice Paggi',
#  'Libreria Editrice Fiorentina',
#  'Liguria',
#  'Lilla (Francia)',
#  'Lingua italiana',
#  'Linz',
#  'Lisbona',
#  'Litfiba',
#  'Lituania',
#  'Liuteria tradizionale cremonese',
#  'Livello del mare',
#  'Liverpool',
#  'Living Theatre',
#  'Livorno',
#  'Lodi',
#  'Loggia dei Lanzi',
#  'Loggia dei Servi di Maria',
#  'Loggia del Grano',
#  'Loggia del Mercato Nuovo',
#  'Lombardia',
#  'Londa',
#  'Londra',
#  'Longobardi',
#  'Longobardi in Italia: i luoghi del potere',
#  'Lorena (dinastia)',
#  'Lorenzo Bartolini',
#  'Lorenzo Ghiberti',
#  "Lorenzo de' Medici",
#  "Lorenzo de' Medici (1599-1648)",
#  'Lorenzo il Magnifico',
#  'Luca Ronconi',
#  'Luca della Robbia',
#  'Lucca',
#  'Luchino Visconti',
#  'Luciano Berio',
#  'Luciano Canepari',
#  'Lucio Cornelio Silla',
#  'Luglio',
#  'Luigi Cherubini',
#  'Luigi Dallapiccola',
#  'Luigi Nono (compositore)',
#  'Luigi Ridolfi',
#  'Luigi Ridolfi Vay da Verrazzano',
#  'Lungarno',
#  'Lungarno Benvenuto Cellini',
#  'Lungarno Corsini',
#  'Lungarno Diaz',
#  'Lungarno Guicciardini',
#  'Lungarno Serristori',
#  'Lungarno Soderini',
#  'Lungarno Torrigiani',
#  'Lungarno Vespucci',
#  'Lungarno degli Acciaiuoli',
#  'Lungarno della Zecca Vecchia',
#  'Lungarno delle Grazie',
#  'Luni',
#  'Lussemburgo',
#  'Lussemburgo (città)',
#  'METAR',
#  'Macbeth (opera)',
#  'Macchiaioli',
#  'Macerata',
#  'Madrid',
#  'Magazzini Criminali',
#  'Maggio',
#  'Maggio Musicale Fiorentino',
#  'Maggio musicale fiorentino',
#  "Maksim Bel'kov",
#  'Malmö',
#  'Malta',
#  'Manierismo',
#  'Manifattura Tabacchi (Firenze)',
#  'Mantova',
#  'Mar Ligure',
#  'Maratona di Firenze',
#  'Marche',
#  'Marco Masini',
#  'Maria Callas',
#  "Maria Teresa d'Austria",
#  'Maribor',
#  'Mario Cecchi Gori',
#  'Mario Del Monaco',
#  'Mark Cavendish',
#  'Marocco',
#  'Marradi',
#  'Marsiglia',
#  'Marzo',
#  'Marzocco (Donatello)',
#  'Masaccio',
#  'Maschera',
#  'Masolino',
#  'Massa (Italia)',
#  'Massimo Ceccherini',
#  'Matera',
#  'Matera capitale europea della cultura',
#  'Mauthausen',
#  'Max Reinhardt',
#  "Medaglia d'Oro al Valor Militare",
#  'Medici',
#  'Medioevo',
#  'Meldola',
#  'Melodramma',
#  'Menarini',
#  'Mercato Centrale (Firenze)',
#  'Mercato Vecchio',
#  'Mercato del Porcellino (Firenze)',
#  'Mercato di San Lorenzo (Firenze)',
#  "Mercato di Sant'Ambrogio",
#  'Mercato ortofrutticolo di Novoli',
#  'Meredith Monk',
#  'Mese',
#  'Messa',
#  'Messico',
#  'Messina',
#  'Metro',
#  'Metro (quotidiano)',
#  'Michelangelo',
#  'Michelangelo Buonarroti',
#  'Michelozzo',
#  'Mike Francis',
#  'Milano',
#  'Millimetro',
#  'Minestra di pane',
#  'Ministero degli affari esteri',
#  "Ministero dell'Istruzione, dell'Università e della Ricerca",
#  'Mino da Fiesole',
#  'Mitropa Cup',
#  'Moda (gruppo musicale)',
#  'Moda a Firenze',
#  'Modena',
#  'Molise',
#  'Monferrato',
#  'Mons',
#  'Montagliari',
#  'Montagna Pistoiese',
#  'Montaione',
#  'Monte Cimino',
#  'Monte San Giorgio (Unesco)',
#  'Montefiascone',
#  'Montelungo',
#  'Montelupo Fiorentino',
#  'Monteriggioni',
#  'Montespertoli',
#  'Monumenti di Firenze',
#  ...]

# %%
# List of URLs of external links on a page. May include external links within page that aren’t technically cited anywhere.
page.references
# Out:
# ['http://climatic.inforef.be/szczecin_rapport/meteorologia/rete.htm',
#  "http://www.avia-it.com/act/editoriali/Editoriali_febbraio_2011/L'aerodromo_del_Campo_di_Marte.pdf",
#  'http://www.bytemuse.com/post/interactive-equivalent-latitude-map/',
#  'http://www.firenze-online.com/visitare/informazioni-firenze.php?id=108',
#  'http://lanazione.ilsole24ore.com/firenze/2008/05/17/89493-gemellaggio_firenze_budapest.shtml',
#  'http://lanazione.ilsole24ore.com/firenze/cronaca/2010/01/22/283821-renzi_obama.shtml',
#  'http://www.ilsole24ore.com/includes2007/speciali/qualita-della-vita/scheda_finale.shtml',
#  'http://www.storiacontinua.com/libri/la-nuova-concezione-di-un-ostacolo-un-romanzo-finanziato-dal-pubblico/',
#  'http://id.loc.gov/authorities/names/n79027120',
#  'http://www.accademia-schermistica-fiorentina.it',
#  'http://www.achillemarozzo.it/',
#  'http://www.beedizioni.it/',
#  'http://www.dipionline.it/dizionario/ricerca?lemma=Firenze',
#  'http://news.comune.fi.it/protezionecivile/wp-content/uploads/2011/06/Tabella_nevicate_significative.pdf',
#  'http://www.comune.fi.it',
#  'http://www.comune.fi.it/export/sites/retecivica/comune_firenze/relazioni_internazionali_cooperazione/gemellaggi.html',
#  'http://www.comune.firenze.it/opencms/export/sites/retecivica/amm/atti_e_documenti/open_data/dataset_0032.html',
#  'http://www.firenzedautore.it/paesi/firenze-16.aspx',
#  'http://www.firenzetoday.it/cronaca/chiusura-city-firenze.html',
#  'http://www.firenzetoday.it/cronaca/giornale-leggo-chiude-firenze-redattori-rischio.html',
#  'http://www.goldworld.it/29204/arts/la-nuova-concezione-di-un-ostacolo/',
#  'http://www.protezionecivile.gov.it/attivita-rischi/rischio-sismico/attivita/classificazione-sismica',
#  'http://www.ilreporter.it',
#  'http://dati.istat.it/Index.aspx',
#  'http://demo.istat.it/bilmens2020gen/index.html',
#  'http://demo.istat.it/str2018/index.html',
#  'http://www.lanazione.it/firenze/cronaca/2012/05/14/712724-nuovo-corriere-chiusura.shtml',
#  'http://www.lanazione.it/firenze/nome-firenze-crusca-1.2076216',
#  'http://www.legambiente.it/sites/default/files/docs/EU2008_0000001280.pdf',
#  'http://www.liberliber.it/mediateca/libri/s/savonarola/trattato_sul_governo_di_firenze/pdf/tratta_p.pdf',
#  'http://www.lungarnofirenze.it',
#  'http://clima.meteoam.it/web_clima_sysman/Clino6190/CLINO170.txt',
#  'http://kigeiblog.myblog.it/archive/2010/01/04/il-david-di-michelangelo-storia-e-descrizione-di-una-emozion.html',
#  'http://www.normattiva.it/uri-res/N2Ls?urn:nir:stato:legge:1993-08-26;412!vig=',
#  'http://www.quirinale.it/elementi/DettaglioOnorificenze.aspx?decorato=3636',
#  'http://www.raggetti.it',
#  'http://www.dizionario.rai.it/poplemma.aspx?lid=56527',
#  'http://www.dizionario.rai.it/poplemma.aspx?lid=56557',
#  'http://firenze.repubblica.it/cronaca/2013/10/08/news/ue_le_murate_scelto_tra_i_100_migliori_progetti_urbani-68186030/',
#  'http://agroambiente.info.arsia.toscana.it/arsia/arsia',
#  'http://static.touring.it/store/document/21_file.pdf',
#  'http://www.tuttitalia.it/toscana/19-comuni/popolazione/',
#  'http://www.ataf.net',
#  'http://www.tutiempo.net/clima/Firenze_Peretola/161700.htm',
#  'http://www.openstreetmap.org/?mlat=43.771388888889&mlon=11.254166666667&zoom=5',
#  'http://www.storiadifirenze.org/?temadelmese=ottobre-1929-uno-nessuno-e-centomila-gli-aeroporti-di-firenze',
#  'https://weatherspark.com/compare/y/15598~69010/Comparison-of-the-Average-Weather-in-Atlanta-and-Florence',
#  'https://weatherspark.com/compare/y/69010~19863/Comparison-of-the-Average-Weather-in-Florence-and-Toronto',
#  'https://toscano27.wordpress.com/2011/07/22/hubert-howard-entrata-a-firenze/',
#  'https://catalogue.bnf.fr/ark:/12148/cb11931414h',
#  'https://data.bnf.fr/ark:/12148/cb11931414h',
#  'https://d-nb.info/gnd/4017581-9',
#  'https://www.comune.fi.it/comunicati-stampa/collesei-e-rossi-art-1-mdp-approvata-nostra-mozione-gemellaggio-di-firenze-con-la?language_content_entity=it',
#  'https://www.comune.fi.it/comunicati-stampa/firenze-vince-il-premio-citta-accessibile-2021-della-commissione-europea?language_content_entity=it',
#  'https://operaduomo.firenze.it/opera',
#  'https://www.publiacqua.it/societa-trasparente',
#  'https://id.ndl.go.jp/auth/ndlna/00629096',
#  'https://web.archive.org/web/20071223013000/http://www.tutiempo.net/clima/Firenze_Peretola/161700.htm',
#  'https://web.archive.org/web/20080423125430/http://associazioni.comune.firenze.it/indice_tematico.htm',
#  'https://web.archive.org/web/20081210031601/http://www.liberliber.it/biblioteca/s/savonarola/',
#  'https://web.archive.org/web/20090301145209/http://www.florenceartfashion.com/',
#  'https://web.archive.org/web/20090416234538/http://www.comune.fi.it/servizi_pubblici/trasporti/piste_ciclabili.htm',
#  'https://web.archive.org/web/20110131135651/http://www.tuttitalia.it/toscana/19-comuni/popolazione/',
#  'https://web.archive.org/web/20110821140354/http://www.firenzedautore.it/paesi/firenze-16.aspx',
#  'https://web.archive.org/web/20120607174933/http://www.firenze-online.com/visitare/informazioni-firenze.php?id=108',
#  'https://web.archive.org/web/20120720085118/http://clima.meteoam.it/web_clima_sysman/Clino6190/CLINO170.txt',
#  'https://web.archive.org/web/20120728234934/http://kigeiblog.myblog.it/archive/2010/01/04/il-david-di-michelangelo-storia-e-descrizione-di-una-emozion.html',
#  'https://web.archive.org/web/20120906083339/http://agroambiente.info.arsia.toscana.it/arsia/arsia',
#  'https://web.archive.org/web/20120927080810/http://www.beedizioni.it/',
#  'https://web.archive.org/web/20121022051729/http://www.firenzetoday.it/cronaca/chiusura-city-firenze.html',
#  'https://web.archive.org/web/20121022052908/http://www.firenzetoday.it/cronaca/giornale-leggo-chiude-firenze-redattori-rischio.html',
#  'https://web.archive.org/web/20121031005501/http://www.lanazione.it/firenze/cronaca/2012/05/14/712724-nuovo-corriere-chiusura.shtml',
#  'https://web.archive.org/web/20121109081326/http://climatic.inforef.be/szczecin_rapport/meteorologia/rete.htm',
#  'https://web.archive.org/web/20130520054207/http://www.ilsole24ore.com/speciali/qvita_2012/home.shtml',
#  'https://web.archive.org/web/20130729122929/http://www.ilsole24ore.com/speciali/qvita_2011/home.shtml',
#  'https://web.archive.org/web/20130731005736/http://www.ilsole24ore.com/speciali/qvita_2009/qvita_2009_settori_classifica_finale.shtml',
#  'https://web.archive.org/web/20130921054740/http://news.comune.fi.it/protezionecivile/wp-content/uploads/2011/06/esondazioni_Arno_Firenze.pdf',
#  'https://web.archive.org/web/20131023055704/http://www.legambiente.it/sites/default/files/docs/EU2008_0000001280.pdf',
#  'https://web.archive.org/web/20131211130657/http://operaduomo.firenze.it/opera/',
#  'https://web.archive.org/web/20140226145829/http://www.storiadifirenze.org/?temadelmese=ottobre-1929-uno-nessuno-e-centomila-gli-aeroporti-di-firenze',
#  'https://web.archive.org/web/20140324025816/http://www.storiacontinua.com/libri/la-nuova-concezione-di-un-ostacolo-un-romanzo-finanziato-dal-pubblico/',
#  'https://web.archive.org/web/20141006072349/http://www.ilsole24ore.com/speciali/qvita_2013/home.shtml',
#  'https://web.archive.org/web/20141006101136/http://www.legambientepiemonte.it/doc/ecosistema%20urbano%202007.pdf',
#  'https://web.archive.org/web/20150914145937/http://www.ilsole24ore.com/speciali/qvita_2014_dati/home.shtml',
#  'https://web.archive.org/web/20160313082219/https://toscano27.wordpress.com/2011/07/22/hubert-howard-entrata-a-firenze/',
#  'https://web.archive.org/web/20160525015629/http://www.lanazione.it/firenze/nome-firenze-crusca-1.2076216',
#  'https://web.archive.org/web/20160804224921/http://www.quirinale.it/elementi/DettaglioOnorificenze.aspx?decorato=3636',
#  'https://web.archive.org/web/20170101172416/http://efficienzaenergetica.acs.enea.it/doc/dpr412-93_allA_tabellagradigiorno.pdf',
#  'https://web.archive.org/web/20170131104307/http://www.ilsole24ore.com/speciali/qvita_2015_dati/home.shtml',
#  'https://web.archive.org/web/20170806142909/http://www.demo.istat.it/bil2016/index.html',
#  'https://web.archive.org/web/20171122082353/http://www.comune.fi.it/export/sites/retecivica/comune_firenze/relazioni_internazionali_cooperazione/gemellaggi.html',
#  'https://web.archive.org/web/20171201080812/http://www.ilsole24ore.com/speciali/qvita_2010/home.shtml',
#  'https://web.archive.org/web/20180524083039/http://firenze.repubblica.it/cronaca/2013/10/08/news/ue_le_murate_scelto_tra_i_100_migliori_progetti_urbani-68186030/',
#  'https://web.archive.org/web/20180619163533/http://www.ilsole24ore.com/includes2007/speciali/qualita-della-vita/scheda_finale.shtml',
#  'https://web.archive.org/web/20180619163607/http://www.ilsole24ore.com/speciali/qvita_2016_dati/home.shtml',
#  'https://web.archive.org/web/20181021192721/http://www.perseoschool.it/',
#  'https://web.archive.org/web/20181202151605/https://weatherspark.com/compare/y/15598~69010/Comparison-of-the-Average-Weather-in-Atlanta-and-Florence',
#  'https://web.archive.org/web/20181202155040/https://weatherspark.com/compare/y/69010~19863/Comparison-of-the-Average-Weather-in-Florence-and-Toronto',
#  'https://web.archive.org/web/20181202155103/http://www.bytemuse.com/post/interactive-equivalent-latitude-map/',
#  'https://web.archive.org/web/20201101013925/https://www.achillemarozzo.it/',
#  'https://web.archive.org/web/20201124203749/http://www.goldworld.it/29204/arts/la-nuova-concezione-di-un-ostacolo/',
#  'https://web.archive.org/web/20201124203752/https://www.comune.fi.it/comunicati-stampa/collesei-e-rossi-art-1-mdp-approvata-nostra-mozione-gemellaggio-di-firenze-con-la?language_content_entity=it',
#  'https://web.archive.org/web/20201124203753/http://www.accademia-schermistica-fiorentina.it/',
#  'https://web.archive.org/web/20201124203753/http://www.raggetti.it/',
#  'https://web.archive.org/web/20201124203806/http://www.ataf.net/en/ataf.aspx?idC=2&LN=en-US',
#  'https://viaf.org/viaf/158387156',
#  'https://www.webcitation.org/6AsJDV3Pn?url=http://static.touring.it/store/document/21_file.pdf',
#  'https://commons.wikimedia.org/wiki/?uselang=it',
#  'https://commons.wikimedia.org/wiki/Category:Florence?uselang=it',
#  'https://tools.wmflabs.org/geohack/geohack.php?language=it&pagename=Firenze&params=43.771389_N_11.254167_E_type:adm3rd_scale:1000000&title=Firenze',
#  'https://www.worldcat.org/identities/lccn-n79027120']

# %%
# Get coordinates - Tuple of Decimals in the form of (lat, lon) or None
page.coordinates
# Out:
# (Decimal('43.77138899999999921419657766819000244140625'),
#  Decimal('11.2541670000000006979234967730008065700531005859375'))

# %% [markdown]
# With the coordinates at hand, we can search what is nearby in Wikipedia.

# %%
# What is nearby?
wikipedia.geosearch(page.coordinates[0],page.coordinates[1], title=None, results=30, radius=2000)
# Out:
# ['Pellegrino (Firenze)',
#  'Provincia di Firenze',
#  'Firenze',
#  'Terremoto di Firenze del 1453',
#  'Circondario di Firenze',
#  'Città metropolitana di Firenze',
#  'Toscana',
#  'Mercato Vecchio',
#  'Piazza della Repubblica (Firenze)',
#  "Chiesa di Sant'Andrea (Firenze)",
#  'Caffè Le Giubbe Rosse',
#  'Torre dei Caponsacchi',
#  'Paszkowski',
#  'Caffè Gilli',
#  'Torre degli Amieri',
#  'Sede storica del Banco di Sicilia',
#  'Chiesa di San Pier Buonconsiglio',
#  'Via degli Speziali',
#  'Chiesa di San Tommaso (Firenze)',
#  'Chiesa di Santa Maria in Campidoglio (Firenze)',
#  'Tabernacolo di Santa Maria della Tromba',
#  'Chiesa di San Leo (Firenze)',
#  'San Matteo (Ghiberti)',
#  "Palazzo dell'Arte della Lana",
#  'Torre dei Macci',
#  'San Giorgio (Donatello)',
#  "Palazzo dell'Arte dei Beccai",
#  "Via de' Tosinghi",
#  'Santo Stefano (Ghiberti)',
#  'Oratorio del Crocifisso dai Vecchietti']

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="https://python-visualization.github.io/folium/_images/folium_logo.jpg" align="left" hspace="10px" vspace="0px"></p>
# <h1>Folium</h1>
#
# **Folium** makes it easy to visualize data that’s been manipulated in Python on an interactive leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing rich vector/raster/HTML visualizations as markers on the map.
#
# The library has a number of built-in tilesets from OpenStreetMap, Mapbox, and Stamen, and supports custom tilesets with Mapbox or Cloudmade API keys. folium supports both Image, Video, GeoJSON and TopoJSON overlays.
#
# Get started  on:
# * https://python-visualization.github.io/folium/quickstart.html#Getting-Started

# %%
#install folium in Google Colab
! pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.8.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.19.5)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from folium) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->folium) (1.1.1)

# %%
# import folium in memory
import folium

# %%
# create a map
import folium
m = folium.Map(location=[55.327431, 14.463191], tiles='Stamen Terrain', zoom_start=10)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_02dcc686187e46e5ad782b0a6bc783e5%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_02dcc686187e46e5ad782b0a6bc783e5%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_02dcc686187e46e5ad782b0a6bc783e5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_02dcc686187e46e5ad782b0a6bc783e5%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B55.327431%2C%2014.463191%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_2c51875254c24917ac58fc942ff60038%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//stamen-tiles-%7Bs%7D.a.ssl.fastly.net/terrain/%7Bz%7D/%7Bx%7D/%7By%7D.jpg%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A% ...

# %%
# Define the area
m = folium.Map(location=[page.coordinates[0],page.coordinates[1]],
               zoom_start=11,
               tiles='Stamen Terrain')
# set the tooltip and popup text data
tooltip = placeName
# load the content of the image from wikipedia page
image = page.images
# define a popupContent as a Html representation
popupContent= folium.Html(f'<div id="" style="overflow:scroll; height:300px;"><h5>'+tooltip+'</h5>'+
                          f'<p><img src={image[0]} class="img-responsive"></p>'+
                          f'<p>{page.summary}</p>'+
                          f'</div>', script=True)
popup= folium.Popup(popupContent, max_width=200)

#creating a Marker on coordinates
folium.Marker([page.coordinates[0],page.coordinates[1]], popup=popup, tooltip=tooltip).add_to(m)

# let's see the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_f2c8b06e9f7246e59999f4bec7d164c6%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f2c8b06e9f7246e59999f4bec7d164c6%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_f2c8b06e9f7246e59999f4bec7d164c6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_f2c8b06e9f7246e59999f4bec7d164c6%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.77138899999999921419657766819000244140625%2C%2011.2541670000000006979234967730008065700531005859375%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_eed08bba9a5443df8d0c1689de6c5a1d%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//stamen-tiles-%7Bs%7D.a.ssl.fastly.net/terrain/%7Bz%7D/%7Bx%7D/%7By%7D.jpg%27%2C%0A%20%20%20% ...

# %% [markdown]
# ## Mapping multiple markers
#
# Now that we know how to put a marker on the place it the idea is to iteratively do it for several markers.
# We will iterate through nearby places, obtained from the Wikipedia API data and represent it on a map as a marker alongside the original marker.
#
# The criteria for obtaining additional markers is: what is near. Nearness is defined with the initial radius of 2000 meters.

# %%
# iterate through nearby places and get data for each place
counter=0
for aPage in wikipedia.geosearch(page.coordinates[0],page.coordinates[1], title=None, results=20, radius=2000):
  try:
    counter=counter+1
    print(counter, aPage)
    print(wikipedia.page(title=aPage).coordinates)
  except:
    print(counter, aPage, 'Does not have coordinates')
    pass
# Out:
# 1 Pellegrino (Firenze)
# 1 Pellegrino (Firenze) Does not have coordinates
# 2 Provincia di Firenze
# (Decimal('43.77138899999999921419657766819000244140625'), Decimal('11.2541670000000006979234967730008065700531005859375'))
# 3 Firenze
# (Decimal('43.77138899999999921419657766819000244140625'), Decimal('11.2541670000000006979234967730008065700531005859375'))
# 4 Terremoto di Firenze del 1453
# (Decimal('43.77138899999999921419657766819000244140625'), Decimal('11.2541670000000006979234967730008065700531005859375'))
# 5 Circondario di Firenze
# (Decimal('43.77138899999999921419657766819000244140625'), Decimal('11.2541670000000006979234967730008065700531005859375'))
# 6 Città metropolitana di Firenze
# (Decimal('43.771388889999997218183125369250774383544921875'), Decimal('11.254166670000000038953658076934516429901123046875'))
# 7 Toscana
# (Decimal('43.771388889999997218183125369250774383544921875'), Decimal('11.254166670000000038953658076934516429901123046875'))
# 8 Mercato Vecchio
# (Decimal('43.771447219999998878847691230475902557373046875'), Decimal('11.2540611100000003119703251286409795284271240234375'))
# 9 Piazza della Repubblica (Firenze)
# (Decimal('43.77138899999999921419657766819000244140625'), Decimal('11.2538889999999991431423040921799838542938232421875'))
# 10 Chiesa di Sant'Andrea (Firenze)
# (Decimal('43.7711479999999966139512252993881702423095703125'), Decimal('11.2542559999999998154862623778171837329864501953125'))
# 11 Caffè Le Giubbe Rosse
# (Decimal('43.77114999999999866986399865709245204925537109375'), Decimal('11.253975000000000505906427861191332340240478515625'))
# 12 Torre dei Caponsacchi
# (Decimal('43.7710670000000021673258743248879909515380859375'), Decimal('11.253989000000000686441126163117587566375732421875'))
# 13 Paszkowski
# (Decimal('43.77180555999999711502823629416525363922119140625'), Decimal('11.25387500000000073896444519050419330596923828125'))
# 14 Caffè Gilli
# (Decimal('43.7718527800000032357274903915822505950927734375'), Decimal('11.2543083300000006374830263666808605194091796875'))
# 15 Torre degli Amieri
# (Decimal('43.77092499999999830606611794792115688323974609375'), Decimal('11.25384700000000037789504858665168285369873046875'))
# 16 Sede storica del Banco di Sicilia
# (Decimal('43.77100555999999897949237492866814136505126953125'), Decimal('11.2546694400000006908157956786453723907470703125'))
# 17 Chiesa di San Pier Buonconsiglio
# (Decimal('43.77154300000000120007825898937880992889404296875'), Decimal('11.2534539999999996240376276546157896518707275390625'))
# 18 Via degli Speziali
# (Decimal('43.77148600000000300269675790332257747650146484375'), Decimal('11.2549139999999994188328855670988559722900390625'))
# 19 Chiesa di San Tommaso (Firenze)
# (Decimal('43.7718220000000002301021595485508441925048828125'), Decimal('11.254716999999999416104401461780071258544921875'))
# 20 Chiesa di Santa Maria in Campidoglio (Firenze)
# 20 Chiesa di Santa Maria in Campidoglio (Firenze) Does not have coordinates
# /usr/local/lib/python3.7/dist-packages/wikipedia/wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /usr/local/lib/python3.7/dist-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %% [markdown]
# # Create a map from iterable geolocations

# %%
m = folium.Map(location=[page.coordinates[0],page.coordinates[1]],
               zoom_start=14,
               tiles='Stamen Terrain')
# iterate
nearby= wikipedia.geosearch(page.coordinates[0],page.coordinates[1], title=None, results=10, radius=5000)
n=0
for aPage in nearby:
  n=n+1
  try:
    coords= wikipedia.page(title=aPage).coordinates
    sum= wikipedia.page(title=aPage).summary
    img = wikipedia.page(title=aPage).images
    ref= wikipedia.page(title=aPage).references
    popupContents= folium.Html(f'<div id="" style="overflow:scroll; height:300px;"><h5>'+aPage.title()+'</h5>'+
                               f'<p><img src={img[0]} class="img-responsive"></p>'+
                               f'<p>{sum}</p>'+
                               f'<p>{ref[0]}</p>'+
                               f'</div>', script=True)
    if n==1:
      icon=folium.Icon(icon='map-marker', color ='red') # https://fontawesome.com/icons?from=io
    else:
      icon=folium.Icon(icon='adjust', color ='blue')
    popups= folium.Popup(popupContents, max_width=300)
    folium.Marker([coords[0],coords[1]], popup=popups, tooltip=aPage, icon= icon).add_to(m)
  except:
    print('Could not create a marker for ', aPage)
    pass
# let's see the map
m
# Out:
# Could not create a marker for  Pellegrino (Firenze)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_248fea7b460f423486eaff196c9ac4d1%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_248fea7b460f423486eaff196c9ac4d1%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_248fea7b460f423486eaff196c9ac4d1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_248fea7b460f423486eaff196c9ac4d1%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.77138899999999921419657766819000244140625%2C%2011.2541670000000006979234967730008065700531005859375%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2014%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_d4751805f0a5428e94fab40b77be9477%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//stamen-tiles-%7Bs%7D.a.ssl.fastly.net/terrain/%7Bz%7D/%7Bx%7D/%7By%7D.jpg%27%2C%0A%20%20%20% ...

# %% [markdown]
# ### Enriching the data
# Once you have created a map you can call the map with just with a variable - in this case: `m`.
#
# This means you can always add to your map something new by using `.add_to(m)` function.

# %% [markdown]
# ### Saving the data

# %%
# you can also save your interactive map as html
m.save('index.html')

# %% [markdown]
# # Combining GoogleMaps with Wikipedia
# ## Get the geolocation from Google and nearby places from Wikipedia
#
# This part uses the GoogleMaps tools explained in the :
# * https://colab.research.google.com/drive/1umGiTylqwvvVWnm_g9MrLSf1xJtemBDf?usp=sharing

# %%
key = 'SHOULD BE FILLED WITH YOUR KEY'

# %%
# !pip install googlemaps
import googlemaps
#from datetime import datetime
# Out:
# Requirement already satisfied: googlemaps in /usr/local/lib/python3.7/dist-packages (4.4.5)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from googlemaps) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2020.12.5)

# %%
placeName= placeName
gmaps = googlemaps.Client(key)
# Geocoding an address
geocode_result = gmaps.geocode(placeName)
geocode_result[0]
# Out:
# {'address_components': [{'long_name': 'suite a',
#    'short_name': 'suite a',
#    'types': ['subpremise']},
#   {'long_name': '3225', 'short_name': '3225', 'types': ['street_number']},
#   {'long_name': 'Vicksburg Lane North',
#    'short_name': 'Vicksburg Ln N',
#    'types': ['route']},
#   {'long_name': 'Plymouth',
#    'short_name': 'Plymouth',
#    'types': ['locality', 'political']},
#   {'long_name': 'Hennepin County',
#    'short_name': 'Hennepin County',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'Minnesota',
#    'short_name': 'MN',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'United States',
#    'short_name': 'US',
#    'types': ['country', 'political']},
#   {'long_name': '55447', 'short_name': '55447', 'types': ['postal_code']}],
#  'formatted_address': '3225 Vicksburg Ln N suite a, Plymouth, MN 55447, USA',
#  'geometry': {'location': {'lat': 45.0182565, 'lng': -93.48392299999999},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 45.0196054802915,
#     'lng': -93.48257401970848},
#    'southwest': {'lat': 45.0169075197085, 'lng': -93.4852719802915}}},
#  'place_id': 'ChIJx38hvS5Ls1IRiHPB96nIk7A',
#  'plus_code': {'compound_code': '2G98+8C Plymouth, MN, USA',
#   'global_code': '86Q82G98+8C'},
#  'types': ['establishment',
#   'food',
#   'meal_delivery',
#   'meal_takeaway',
#   'point_of_interest',
#   'restaurant']}

# %%
geoPosition= geocode_result[0]['geometry']['location']
geoPosition
# Out:
# {'lat': 45.0182565, 'lng': -93.48392299999999}

# %%
try:
  countryCode = geocode_result[0]['address_components'][6]
  countryCode
except:
  pass

# %%
wikipedia.set_lang("it")

# %%
# What is nearby in the wikipedia?
wikipedia.geosearch(geoPosition['lat'],geoPosition['lng'], title=None, results=10, radius=10000)
# Out:
# ['Plymouth (Minnesota)',
#  'Wayzata',
#  'Medicine Lake (Minnesota)',
#  'Maple Grove (Minnesota)',
#  'Medina (Minnesota)',
#  'Woodland (Minnesota)',
#  'Long Lake (Minnesota)',
#  'New Hope (Minnesota)',
#  'Crystal (Minnesota)']
